# %%
import sys
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

from scipy.special import expit
from scipy import sparse
from scipy.sparse import csr_matrix

#from sklearn.model_selection import StratifiedKFold
from sklearn.cross_validation import StratifiedKFold

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from sklearn.cluster import KMeans

from xgboost.sklearn import XGBClassifier
from xgboost.core import DMatrix
from xgboost.training import train, cv
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train_file = 'Dataset\\train.json'
test_file = 'Dataset\\test.json'
print('load data', datetime.datetime.now())
df_train = pd.read_json(train_file)
df_test = pd.read_json(test_file)
print(df_train.shape)
print(df_test.shape)
print('load data done', datetime.datetime.now())

target_num_map = {'high':0, 'medium':1, 'low':2}
y_train = np.array(df_train['interest_level'].apply(lambda x: target_num_map[x]))
df_train = df_train.drop(['interest_level'], axis=1)
# Out:
# load data 2017-03-09 14:46:38.612256
# (49352, 15)
# (74659, 14)
# load data done 2017-03-09 14:46:48.804152

# %%
def feature_engineering(df_train, df_test, y_train):
    print('feature engineering', datetime.datetime.now())

    #for some reason listing_id improves the score

    #df_train.index = df_train['listing_id']
    #df_train = df_train.drop(['listing_id'], axis=1)

    #df_test.index = df_test['listing_id']
    #df_test = df_test.drop(['listing_id'], axis=1)

    #ignore_Index because use sort_index later.
    df_all = pd.concat((df_train, df_test), axis=0, ignore_index=True)

    ###
    ###date feature
    ###
    df_all['created'] = pd.to_datetime(df_all['created'])
    #year - all 2016
    #df['created_year'] = df['created'].dt.year
    df_all['created_month'] = df_all['created'].dt.month
    df_all['created_day'] = df_all['created'].dt.day
    df_all['created_day_of_year'] = df_all['created'].dt.strftime('%j').astype(int)
    df_all['created_hour'] = df_all['created'].dt.hour
    df_all['created_weekday'] = df_all['created'].dt.weekday
    df_all = df_all.drop(['created'], axis=1)

    '''
    #create_weekday categorical
    ohe = OneHotEncoder(sparse=False)
    df_all_ohe = ohe.fit_transform(df_all.created_weekday.reshape(-1, 1)) 	
    for i in range(df_all_ohe.shape[1]):
        df_all['ohe' + str(i)] = df_all_ohe[:, i]
    df_all = df_all.drop(['created_weekday'], axis=1)
    '''
    ###
    ### numeric features
    ###
    #adjust incorrect x/y
    x_mean = df_all.latitude.mean()
    y_mean = df_all.longitude.mean()

    df_all.loc[df_all.latitude < x_mean - 5, 'latitude'] = x_mean - 5
    df_all.loc[df_all.latitude > x_mean + 5, 'latitude'] = x_mean + 5
    df_all.loc[df_all.longitude < y_mean - 5, 'longitude'] = y_mean - 5
    df_all.loc[df_all.longitude > y_mean + 5, 'longitude'] = y_mean + 5

    '''
    #adjust incorrect x/y by percentile
    percentile = 0.1
    llimit = np.percentile(df_all.latitude.values, percentile)
    ulimit = np.percentile(df_all.latitude.values, 100 - percentile)
    df_all.loc[df_all['latitude']<llimit, 'latitude'] = llimit
    df_all.loc[df_all['latitude']>ulimit, 'latitude'] = ulimit
    llimit = np.percentile(df_all.longitude.values, percentile)
    ulimit = np.percentile(df_all.longitude.values, 100 - percentile)
    df_all.loc[df_all['longitude']<llimit, 'longitude'] = llimit
    df_all.loc[df_all['longitude']>ulimit, 'longitude'] = ulimit
    '''

    #log x/y
    df_all['logx'] = np.log(df_all['latitude'])
    df_all['logy'] = np.log(df_all['longitude'] + 100)

    #radius
    df_all['radius'] = np.log((df_all.latitude - x_mean)*(df_all.latitude - x_mean) + (df_all.longitude - y_mean)*(df_all.longitude - y_mean))

    #price
    #df_all.loc[df_all['price'] > 100000, 'price'] = 100000

    #log price
    #df_all['logprice'] = np.log(df_all.price)

    df_all["price_per_bed"] = df_all["price"]/df_all["bedrooms"] 
    df_all["room_dif"] = df_all["bedrooms"] - df_all["bathrooms"] 
    df_all["room_sum"] = df_all["bedrooms"] + df_all["bathrooms"] 
    df_all["price_per_room"] = df_all["price"]/df_all["room_sum"]

    df_all["photos_count"] = df_all["photos"].apply(len)
    df_all = df_all.drop(['photos'], axis=1)
    
    ###
    ###zones
    ###
    n_zones = 140
    x_min = df_all.logx.mean() - 0.004
    x_max = df_all.logx.mean() + 0.003
    y_min = df_all.logy.mean() - 0.003
    y_max = df_all.logy.mean() + 0.003

    df_all2 = df_all[(df_all.logx >= x_min) & (df_all.logx <= x_max) & (df_all.logy >= y_min) & (df_all.logy <= y_max)]
    kmeans = KMeans(n_clusters=n_zones, random_state=0).fit(df_all2[['logx', 'logy']])

    print('zones', df_all.shape)

    for i in range(n_zones):
        df_all['zone' + str(i)] = 0
        df_all.loc[df_all2.logx[kmeans.labels_ == i].index, 'zone' + str(i)] = 1

    print('zones', df_all.shape)

    ###
    ###description
    ###
    df_all['description'] = df_all['description'].apply(lambda x: cleaning_text(x))
    df_all["description_words_count"] = df_all["description"].apply(lambda x: 0 if len(x) == 0 else len(x.split(" ")))
    df_all['description_uppercase'] = df_all['description'].apply(lambda x: 1 if len(re.findall(r'[A-Z]', x))/(len(x) + 1) > 0.5 else 0)
    df_all['description'] = df_all['description'].apply(lambda x: x.lower())

    '''
    n_features2 = 100
    tfidf2 = CountVectorizer(stop_words='english', max_features=n_features2)
    tr_sparse2 = tfidf2.fit_transform(df_all[:df_train.shape[0]]['description'])
    te_sparse2 = tfidf2.transform(df_all[df_train.shape[0]:]['description'])
    '''
    #df_all = df_all.drop(['description'], axis=1)

    ###
    ### features
    ###
    df_all["features_count"] = df_all["features"].apply(len)

    '''
    n_features = 2000
    df_all['features'] = df_all['features'].apply(lambda x: cleaning_list(x))
    df_all['features'] = df_all['features'].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))
    df_all['features'] = df_all['features'].apply(lambda x: x.lower())
    tfidf = CountVectorizer(stop_words='english', max_features=n_features)
    tr_sparse = tfidf.fit_transform(df_all[:df_train.shape[0]]['features'])
    te_sparse = tfidf.transform(df_all[df_train.shape[0]:]['features'])

    df_all = df_all.drop(['features'], axis=1)
    '''
    
    ###
    ###display and street address
    ###
    df_all['display_address'] = df_all.display_address.str.replace('Avenue', '')
    df_all['display_address'] = df_all.display_address.str.replace(' Ave', '')
    df_all['display_address'] = df_all.display_address.str.replace('Street', '')
    df_all['display_address'] = df_all.display_address.str.replace('St.', '')
    df_all['display_address'] = df_all.display_address.str.replace(' St', '')
    df_all['display_address'] = df_all.display_address.str.rstrip()

    df_all['street_address'] = df_all.street_address.str.replace('Avenue', '')
    df_all['street_address'] = df_all.street_address.str.replace(' Ave', '')
    df_all['street_address'] = df_all.street_address.str.replace('Street', '')
    df_all['street_address'] = df_all.street_address.str.replace('St.', '')
    df_all['street_address'] = df_all.street_address.str.replace(' St', '')
    df_all['street_address'] = df_all.street_address.str.rstrip()

    #keep only the first int from street_address - not a good idea, just the number without street is useless
    #df_all['street_address'] = df_all.street_address.apply(lambda x: x.split(" ")[0])

    ###
    ###categorical features
    ###
    #cannot make them ohe - too many distinct values
    ohe_features = ['building_id', 'display_address', 'manager_id', 'street_address'] 
    for f in ohe_features: 
        le = LabelEncoder() 
        df_all[f] = le.fit_transform(df_all[f]) 

    ###
    ###building_id, manager_id
    ###
    value_counts = df_all['building_id'].value_counts()
    df_all = pd.merge(df_all, pd.DataFrame(value_counts), left_on='building_id', right_index=True).sort_index()
    df_all = df_all.drop(['building_id_x'], axis=1)    
    df_all.loc[df_all.building_id == 0, 'building_id_y'] = 0

    value_counts = df_all['manager_id'].value_counts()
    df_all = pd.merge(df_all, pd.DataFrame(value_counts), left_on='manager_id', right_index=True).sort_index()
    df_all = df_all.drop(['manager_id_x'], axis=1)    
    df_all.loc[df_all.manager_id == 0, 'manager_id_y'] = 0

    print(df_all.shape)

    #done
    X_train = df_all[:df_train.shape[0]]
    X_test = df_all[df_train.shape[0]:]

    #X_train = pd.concat((X_train, pd.DataFrame(tr_sparse.todense())), axis=1)
    #X_test = pd.concat((X_test, pd.DataFrame(te_sparse.todense())), axis=1)

    #X_train = csr_matrix(np.hstack([X_train, tr_sparse.todense()]))
    #X_test = csr_matrix(np.hstack([X_test, te_sparse.todense()]))
    #X_train = csr_matrix(np.hstack([X_train, tr_sparse.todense(), tr_sparse2.todense()]))
    #X_test = csr_matrix(np.hstack([X_test, te_sparse.todense(), te_sparse2.todense()]))

    print('Train', X_train.shape)
    print('Test', X_test.shape)

    print('feature engineering done', datetime.datetime.now())
    return X_train, X_test

# %%
ENGLISH_STOP_WORDS = frozenset([
    "a", "about", "above", "across", "after", "afterwards", "again", "against",
    "all", "almost", "alone", "along", "already", "also", "although", "always",
    "am", "among", "amongst", "amoungst", "amount", "an", "and", "another",
    "any", "anyhow", "anyone", "anything", "anyway", "anywhere", "are",
    "around", "as", "at", "back", "be", "became", "because", "become",
    "becomes", "becoming", "been", "before", "beforehand", "behind", "being",
    "below", "beside", "besides", "between", "beyond", "bill", "both",
    "bottom", "but", "by", "call", "can", "cannot", "cant", "co", "con",
    "could", "couldnt", "cry", "de", "describe", "detail", "do", "done",
    "down", "due", "during", "each", "eg", "eight", "either", "eleven", "else",
    "elsewhere", "empty", "enough", "etc", "even", "ever", "every", "everyone",
    "everything", "everywhere", "except", "few", "fifteen", "fifty", "fill",
    "find", "fire", "first", "five", "for", "former", "formerly", "forty",
    "found", "four", "from", "front", "full", "further", "get", "give", "go",
    "had", "has", "hasnt", "have", "he", "hence", "her", "here", "hereafter",
    "hereby", "herein", "hereupon", "hers", "herself", "him", "himself", "his",
    "how", "however", "hundred", "i", "ie", "if", "in", "inc", "indeed",
    "interest", "into", "is", "it", "its", "itself", "keep", "last", "latter",
    "latterly", "least", "less", "ltd", "made", "many", "may", "me",
    "meanwhile", "might", "mill", "mine", "more", "moreover", "most", "mostly",
    "move", "much", "must", "my", "myself", "name", "namely", "neither",
    "never", "nevertheless", "next", "nine", "no", "nobody", "none", "noone",
    "nor", "not", "nothing", "now", "nowhere", "of", "off", "often", "on",
    "once", "one", "only", "onto", "or", "other", "others", "otherwise", "our",
    "ours", "ourselves", "out", "over", "own", "part", "per", "perhaps",
    "please", "put", "rather", "re", "same", "see", "seem", "seemed",
    "seeming", "seems", "serious", "several", "she", "should", "show", "side",
    "since", "sincere", "six", "sixty", "so", "some", "somehow", "someone",
    "something", "sometime", "sometimes", "somewhere", "still", "such",
    "system", "take", "ten", "than", "that", "the", "their", "them",
    "themselves", "then", "thence", "there", "thereafter", "thereby",
    "therefore", "therein", "thereupon", "these", "they", "thick", "thin",
    "third", "this", "those", "though", "three", "through", "throughout",
    "thru", "thus", "to", "together", "too", "top", "toward", "towards",
    "twelve", "twenty", "two", "un", "under", "until", "up", "upon", "us",
    "very", "via", "was", "we", "well", "were", "what", "whatever", "when",
    "whence", "whenever", "where", "whereafter", "whereas", "whereby",
    "wherein", "whereupon", "wherever", "whether", "which", "while", "whither",
    "who", "whoever", "whole", "whom", "whose", "why", "will", "with",
    "within", "without", "would", "yet", "you", "your", "yours", "yourself",
    "yourselves"])

# %%
def cleaning_text(text):
    #sentence=sentence.lower()
    text = text.replace('<p><a  website_redacted', '')
    text = text.replace('!<br /><br />', '')
    text = text.replace('kagglemanager renthop com', '')
    text = re.sub('[^\w\s]',' ', text) #removes punctuations
    text = re.sub('\d+',' ', text) #removes digits
    text =' '.join([w for w in text.split() if not w in ENGLISH_STOP_WORDS]) # removes english stopwords
    #text=' '.join([w for w , pos in pos_tag(text.split()) if (pos == 'NN' or pos=='JJ' or pos=='JJR' or pos=='JJS' )])
    #selecting only nouns and adjectives
    text =' '.join([w for w in text.split() if not len(w)<=2 ]) #removes single lettered words and digits
    text = text.strip()
    return text

def cleaning_text2(text):
    text = re.sub('[^\w\s]',' ', text) #removes punctuations
    #text = re.sub('\d+',' ', text) #removes digits
    #text =' '.join([w for w in text.split() if not len(w)<=2 ]) #removes single lettered words and digits
    text = text.strip()
    return text

def cleaning_list(list):
    return [cleaning_text2(x) for x in list]
    #return map(cleaning_text, list)

# %%
X_train, X_test = feature_engineering(df_train, df_test, y_train)
# Out:
# feature engineering 2017-03-09 21:11:43.385234
# zones (124011, 25)
# zones (124011, 165)
# (124011, 170)
# Train (49352, 170)
# Test (74659, 170)
# feature engineering done 2017-03-09 21:12:44.771078

# %%
X_train.description
# Out:
# 0        brand new bedroom bath apartmentenjoy these fo...
# 1
# 2        top top west village location beautiful pre wa...
# 3        building amenities garage garden fitness room ...
# 4        beautifully renovated bedroom flex bedroom apa...
# 5
# 6        stunning unit great location lots natural ligh...
# 7        this huge sunny plenty lights bed bath offers ...
# 8
# 9        this spacious bedroom bedroom able fit queen s...
# 10       new market spacious studio located maintained ...
# 11       check bedroom apartment great location washing...
# 12       low fee beautiful cherry oak wooden floorsthe ...
# 13       lincoln square premier service buildings locat...
# 14       spacious bedroom fit king sized bed comfortabl...
# 15       stunning renovated studio unit high ceilings s...
# 16       east village great community great people offe...
# 17       location thayer amp broadway manhattan this ph...
# 18
# 19
# 20       beautiful bedroom possible conversion into thr...
# 21       fee huge bedroom apartment great location clos...
# 22
# 23       coopercooper com web access unique listings on...
# 24       sprawling bedroom found enjoy the luxury full ...
# 25       amazing bedroom convertible remarkably luxurio...
# 26       don miss fantastic apartment spacious bdr affo...
# 27       the true bedroom apartment features extra larg...
# 28       currently renovation bedroom going beautiful c...
# 29       gut renovated apartment stainless steel applia...
#                                ...
# 49322    elegant spacious bedroom modern luxury buildin...
# 49323
# 49324    important notice planning moving days urgent s...
# 49325    washer dryer unit minute walk train bright sun...
# 49326    tremendous classic six luxurious prewar doorma...
# 49327    luxury living full time doorman concierge serv...
# 49328    only block form washington square park new gut...
# 49329    this residence features stainless steal applia...
# 49330    this newly renovated bedroom unit recently ren...
# 49331    bedroom living room awesome spacious opportuni...
# 49332    don miss spacious beautiful upper west side be...
# 49333    this exquisitely appointed bedroom bath reside...
# 49334    this spacious bedroom apartment features energ...
# 49335    great lower east side bedroom well maintained ...
# 49336    this large and spacious one apartment has hard...
# 49337    fully gut renov studio ceil xpsd brick amazing...
# 49338    full time doorman pet friendlyelevator gymlaun...
# 49339    this great opportunity rent excellent bed flex...
# 49340
# 49341    incredibly sunny spacious studio apartment lux...
# 49342    luxury building midtown west doorman close all...
# 49343    huge true king size bedroom elevator building ...
# 49344    charming bedroom hardwood floors sunny clean s...
# 49345    park ave block central park huge kitchen livin...
# 49346    doorman luxury building heart east village bui...
# 49347    massive conv luxury full service building the ...
# 49348    high end condo finishes swimming pool king siz...
# 49349    large renovated one bedroom apartment stainles...
# 49350    stylishly sleek studio apartment unsurpassed a...
# 49351    look this giant bedroom apartment located soug...
# Name: description, dtype: object

# %%
df_all = pd.concat((X_train, X_test), axis=0, ignore_index=True)
df_all['features2'] = df_all['features'].apply(lambda x: cleaning_list(x))
df_all['features2'] = df_all['features2'].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))
#df_all['features2'] = df_all['features2'].apply(lambda x: x.lower())
df_all.features2
# Out:
# 0
# 1         Doorman Elevator Fitness_Center Cats_Allowed D...
# 2         Laundry_In_Building Dishwasher Hardwood_Floors...
# 3                                    Hardwood_Floors No_Fee
# 4                                                   Pre_War
# 5
# 6         prewar elevator Dogs_Allowed Cats_Allowed LOWR...
# 7         Doorman Elevator Pre_War Terrace Laundry_in_Un...
# 8         Cats_Allowed Dogs_Allowed Elevator Laundry_In_...
# 9                                Dishwasher Hardwood_Floors
# 10
# 11        prewar dishwasher HIGHRISE ROOFDECK EAT_IN_KIT...
# 12              Doorman Elevator Laundry_in_Building No_Fee
# 13        Swimming_Pool Doorman Fitness_Center No_Fee Do...
# 14        Elevator Multi_Level Laundry_in_Building Dishw...
# 15        Doorman Elevator Fitness_Center Laundry_in_Bui...
# 16                                          Hardwood_Floors
# 17           prewar LOWRISE EAT_IN_KITCHEN SIMPLEX HARDWOOD
# 18                         No_Fee Cats_Allowed Dogs_Allowed
# 19                                Cats_Allowed Dogs_Allowed
# 20              Doorman Elevator Dishwasher Hardwood_Floors
# 21        Elevator Central_A_C Walk_in_Closet_s Parking ...
# 22                                Cats_Allowed Dogs_Allowed
# 23        Doorman Fitness_Center Pool Elevator PublicOut...
# 24        Balcony Doorman Elevator Fitness_Center Terrac...
# 25        Roof_Deck Dining_Room Balcony Doorman Elevator...
# 26                        Dishwasher Hardwood_Floors No_Fee
# 27        Roof_Deck Doorman Elevator Laundry_in_Building...
# 28
# 29        Doorman Elevator Fitness_Center Pre_War Laundr...
#                                 ...
# 123981    Swimming_Pool Roof_Deck Doorman Elevator Fitne...
# 123982    Dining_Room Doorman Elevator Laundry_in_Buildi...
# 123983
# 123984           Elevator Pre_War Dogs_Allowed Cats_Allowed
# 123985    Swimming_Pool Dining_Room Doorman Elevator Fit...
# 123986    Doorman Elevator Fitness_Center Common_garden ...
# 123987    Fireplace Dining_Room Elevator Garden_Patio Mu...
# 123988             Swimming_Pool Roof_Deck Doorman Elevator
# 123989                               Hardwood_Floors No_Fee
# 123990        Cats_Allowed Dogs_Allowed Laundry_In_Building
# 123991    Dining_Room Balcony Doorman Elevator Laundry_i...
# 123992             Fitness_Center Cats_Allowed Dogs_Allowed
# 123993    Dining_Room Doorman Elevator Laundry_in_Buildi...
# 123994            Elevator No_Fee Cats_Allowed Dogs_Allowed
# 123995    Dishwasher Hardwood_Floors Dogs_Allowed Cats_A...
# 123996    Swimming_Pool Doorman Elevator Fitness_Center ...
# 123997                           Dishwasher Hardwood_Floors
# 123998    Doorman Prewar Elevator Hardwood_Floors High_C...
# 123999                                  Laundry_in_Building
# 124000    Roof_Deck Elevator Fitness_Center Laundry_in_B...
# 124001                          Loft Hardwood_Floors No_Fee
# 124002    Doorman Elevator Laundry_in_Building Dishwashe...
# 124003    Dining_Room Doorman Elevator Fitness_Center Te...
# 124004                                              Pre_War
# 124005                                      Doorman Pre_War
# 124006                    Pre_War Dogs_Allowed Cats_Allowed
# 124007
# 124008    Doorman Elevator Pre_War Laundry_in_Building L...
# 124009                Cats_Allowed Dogs_Allowed Reduced_Fee
# 124010                   Elevator Dogs_Allowed Cats_Allowed
# Name: features2, dtype: object

# %%
tfidf = CountVectorizer(stop_words='english', max_features=2000)
tr_sparse = tfidf.fit_transform(df_all[:df_train.shape[0]]['features2'])
print(len(tfidf.get_feature_names()))
tfidf.get_feature_names()
# Out:
# 1230
# ['000_sf_fitness_center',
#  '000_sq__ft__landscaped_terrace_complete_with_an_organic_garden',
#  '000_square_foot_exclusive_courtyard_oasis_for_via_residents',
#  '000_square_foot_sun_deck__free_wifi_in_marc_club',
#  '1000__move_in_visa_giftcard_will_be_handed_to_new_tenants_upon_rental_lease_signing',
#  '1100_sq_ft',
#  '1200sq_ft',
#  '12th_st___3rd_ave',
#  '1500__move_in_visa_giftcard_will_be_handed_to_new_tenants_upon_rental_lease_signing',
#  '1_2_bath',
#  '1_2_month_fee',
#  '1_5_bath',
#  '1_5_bathrooms',
#  '1_5_baths',
#  '1_5_marble_baths',
#  '1_br_or_conv_2',
#  '1_mo_broker_s_fee_18_mo_lease',
#  '1_month_free',
#  '1_month_free_rent',
#  '1st',
#  '22',
#  '24_7_concierge',
#  '24_7_doorman',
#  '24_7_doorman_concierge',
#  '24_7_fitness_center',
#  '24_7_full_time_doorman_concierge',
#  '24_hour_attended_lobby',
#  '24_hour_concierge',
#  '24_hour_concierge_and_doorman',
#  '24_hour_doorman',
#  '24_hour_doorman_concierge',
#  '24_hour_parking_garage_with_an_electric_vehicle_charging_station',
#  '24_hr_concierge',
#  '24_hr_doorman',
#  '24hr_doorman',
#  '24hr_doormen',
#  '24hr_white_gloved_doorman',
#  '24th_st___3rd_ave',
#  '250_application_fee_with_background_and_credit_check__board_interview_and_approval',
#  '250_security_deposit',
#  '25lb_weight_limit_on_pet',
#  '2_bathrooms',
#  '2_beautifully_furnished_outside_sundecks',
#  '2_bedroon_convertible',
#  '2_blocks_away_from_union_square',
#  '2_full_bathrooms',
#  '2_full_baths',
#  '2_months_free',
#  '2_queen_bedrooms',
#  '2_story_tenant_lounge',
#  '2_year_lease',
#  '2nd_ave',
#  '30',
#  '30th___3rd_ave',
#  '30th_st___madison_avenue',
#  '36th_st___3rd_ave',
#  '3_12_month_leases_allowed',
#  '3_ac',
#  '3_bath',
#  '3br',
#  '4_roof_decks_with_river_views',
#  '4_train_is_less_than_1_block_away',
#  '4th_floor_walk_up',
#  '4th_off_charles',
#  '500_security_deposit',
#  '500_sq_ft',
#  '50_ft__exercise_pool_and_whirlpool_with_lifeguard_on_duty',
#  '55th___6th_ave',
#  '5_bed',
#  '600_gift_card_for_move_ins_prior_to_june_19',
#  '65th_2nd_ave',
#  '6_bedrooms',
#  '700_sf',
#  '73rd_st',
#  '75th___1st',
#  '78th___lexington_ave',
#  '79th_2nd',
#  '81st___cpw',
#  '87th___1st',
#  '9th_floor_manhattan_views',
#  'a_c',
#  'a_c_units',
#  'a_full_service_luxury_highrise',
#  'a_full_service_luxury_residence',
#  'a_one_of_a_kind_full_service_luxury_highrise',
#  'a_true_top_luxury_hi_rise',
#  'a_wide_array_of_complimentary_fitness_classes_offered_weekly',
#  'absolute_value_for_size___location',
#  'abundant_closets',
#  'ac',
#  'ac_central',
#  'accepts_credit_cards__fee_applies',
#  'ached_doorways',
#  'act_fast_will_not_last',
#  'act_fast_wont_last',
#  'actual_apt__photos',
#  'actual_photos',
#  'air_condition',
#  'air_conditioned',
#  'air_conditioned_laundry_facility',
#  'air_conditioning',
#  'air_conditioning__unknown_type',
#  'alcove',
#  'alcove_studio',
#  'all_brand_new_no_fee____expansive_2br_mcmansion___private_terrace___cook_s_ss_kitchen___elev_lndry_bldg___3_blks_to_l_train',
#  'all_common_areas_feature_wi_fi_accessibility',
#  'all_kitchen_appliances_included',
#  'all_new',
#  'all_pets_ok',
#  'all_utilities_included',
#  'amazing_deal',
#  'amazing_detail',
#  'ample_closet_space',
#  'ample_sofa_bed_in_living_space_for_extra_accommodations',
#  'an_expansive_landscaped_terrace_and_sun_deck',
#  'and_breathtaking_views_of_new_york_city_from_our_rooftop_terrace',
#  'and_rcn',
#  'and_stainless_steel_appliances_with_a_dishwasher_well_maintained_hardwood_floors_add_to_the_warmth_and_modern_feel_of_the_space',
#  'approved_animals_only',
#  'arched_doorways',
#  'arguably_the_most_well_maintained_luxury_highrise_in_the_city',
#  'assigned_parking_space',
#  'at_an_additional_cost',
#  'atm',
#  'atm_machine_on_site',
#  'attached_garage',
#  'attached_parking',
#  'attached_parking_garage',
#  'attended_garage',
#  'attended_garage_and_service_entrance',
#  'attended_lobby',
#  'available_05_01_16',
#  'available_06_01_16',
#  'available_06_04_16_____firepalce',
#  'available__04_15_16',
#  'available__05_01_16______swimming_pool_________dishwasher',
#  'available__05_15_16____dishwasher',
#  'available__07_01_16',
#  'b_billiards_table',
#  'backyard',
#  'balconies_in_both_bedrooms',
#  'balcony',
#  'balocny',
#  'baruch',
#  'basement_storage',
#  'basketball_court',
#  'bay_windows',
#  'bbq_grill',
#  'bbqs',
#  'beamed_ceilings',
#  'bicycle_and_tenant_st___orage_available_for_rent',
#  'bicycle_room',
#  'bicycle_room_and_individual_resident_storage',
#  'bicycle_storage',
#  'big_2_bed_deal__grab_it_or_grieve_it',
#  'big_closets',
#  'big_open_spaces',
#  'big_rooms',
#  'bike___stroller_storage',
#  'bike_room',
#  'bike_storage',
#  'billiards_and_shuffle_board_game_room_poker_room_golf_simulator_and_putting_green',
#  'billiards_lounge',
#  'billiards_room',
#  'billiards_table_and_wet_bar',
#  'bklyn_s_finest____massive_true_2br___courtyard___fully_renovated___2_blks_to_bedford_l_stop',
#  'bluetooth',
#  'bluetooth_system',
#  'boating_hardwood_floors',
#  'brand_new',
#  'brand_new_appliances',
#  'brand_new_renovation',
#  'brand_new_ss_appliances',
#  'brand_new_ss_kitchen',
#  'brand_new_stainless_steal_appliances',
#  'brand_new_stainless_steel_appliances',
#  'brand_new_washer___dryer',
#  'brand_newm_outdoor_deck',
#  'brand_spankin__new___oversized_3br_home___washer_dryer___ss_kitchen_w_island___heart_of_desirable_soho',
#  'brand_spanking_new',
#  'breakfast_bar',
#  'bridge_view',
#  'bright',
#  'bright___sunny',
#  'bright_spacious_2_br_1ba',
#  'bring_ur_bbq____sprawling_2br_home___huge_rear_terrace___modern_everything___chef_s_kitchen___all_new',
#  'broker_fee',
#  'brownstone',
#  'brownstone_beauty___massive_2br_home___steps_to_the_park___ss_kitchen___dishwasher___oversized_closets___near_columbia_u',
#  'build_in_microwave_oven',
#  'building_common_outdoor_space',
#  'building_link_notification___key_track_for_tenants_convenience',
#  'building_storage',
#  'built_in_ac',
#  'built_in_breakfast_bar',
#  'built_in_microwave',
#  'built_in_office_area',
#  'built_in_speaker_system',
#  'built_in_storage',
#  'built_in_wine_cooler',
#  'business_center',
#  'cable_ready',
#  'cable_satellite_tv',
#  'call_text_abraham_caro___917_373_0862',
#  'call_timur_for_instant_access_646_847_8588',
#  'catering_facility',
#  'cats_allowed',
#  'cats_on_approval',
#  'ceiling_fan',
#  'ceiling_fan__3lg_closets',
#  'ceiling_fans',
#  'central_a_c',
#  'central_ac',
#  'central_air',
#  'central_air_conditioning',
#  'central_heat',
#  'central_park_1_2_block_away',
#  'central_park_steal____massive_studio_supreme___gut_renovated___walls_of_windows___elev_lndry_bldg',
#  'chef_s_kitchen',
#  'chefs_kitchen',
#  'chelsea',
#  'chelsea_baby____massive_2br_super_share___all_modern___new___elev__lndry_bldg',
#  'chic_chelsea_find____massive_4br_home___2_full_baths___chef_inspired_kitchen___elev_that_opens_into_apt___cats_ok',
#  'chic_chelsea_steal____super_sweet_studio___gourmet_chef_s_kitchen___all_modern___new___tons_of_storage___pets_ok',
#  'children_playroom',
#  'children_s_playroom',
#  'children_s_room',
#  'childrens_playroom',
#  'childrens_room',
#  'cinema_room',
#  'citi_bike_station',
#  'citibikes_nearby',
#  'city_view',
#  'classy_clinton_home___massive_1br___gourmet_kitchen___exposed_brick___roomy_closets',
#  'classy_condo_gem____massive_2br_super_share___gourmet_kitchen___perfect_sun___chic_chelsea_locale',
#  'classy_conv_2br_duplex_dream____room_to_entertain___lndry_bldg___cats_ok___heart_of_the_village',
#  'classy_corner_studio___oversized___underpriced___windows_all_around___pets_ok',
#  'classy_corner_studio_supreme___walls_of_windows___all_modern___new___pets_ok',
#  'close_to_central_park',
#  'close_to_hospitals',
#  'close_to_nyc',
#  'close_to_subway',
#  'close_to_subway___renovated',
#  'close_to_transit',
#  'closed_circuit_television_security_system',
#  'closet_space',
#  'closets',
#  'closets_galore',
#  'club_room',
#  'club_room_w_billiards_tables',
#  'club_sun_deck_has_spectacular_city_and_river_views',
#  'co_op',
#  'cold_storage',
#  'cold_storage_in_lobby',
#  'combo_washer_dryer',
#  'come_live_the_good_life_for__less',
#  'common_areas',
#  'common_backyard',
#  'common_balcony',
#  'common_courtyard',
#  'common_garden',
#  'common_outdoor_space',
#  'common_parking_garage',
#  'common_roof_deck',
#  'common_storage',
#  'common_terrace',
#  'community_recreation_facilities',
#  'commuter_s_paradise',
#  'competitively_priced',
#  'complimentary_breakfast_on_weekdays',
#  'complimentary_continental_breakfast',
#  'complimentary_sunday_brunch',
#  'comprehensive_valet_services_including_maid_service',
#  'concierge',
#  'concierge_and_live_in_super',
#  'concierge_service',
#  'concierge_service__fitness_center',
#  'concierge_services',
#  'condo_finishes',
#  'condo_grade_finishes',
#  'continental_breakfast_served_5_days_a_week',
#  'control___pay_for_your_own_heat_with_your_own_thermostat',
#  'conv__3_bedroom',
#  'convertible_1br',
#  'convertible_2',
#  'convertible_2_bedroom',
#  'convinient_to_all_major_transportation',
#  'corner_unit',
#  'counter_top_space',
#  'court_square_gem____lic_luxury_2br_home___ss_kitchen___dishwasher___bay_windows___fireplace___all_new',
#  'court_square_gem____sprawling_sundrenched_2br_home___custom_finishes___dishwasher___fireplaces___eat_in_kitchen___bay_windows',
#  'courtyard',
#  'crown_molding',
#  'crown_moldings',
#  'custom_lighting',
#  'custom_murals_on_the_ceiling_and_living_room_wall__painted_my_a_local_artist',
#  'custom_painted_murals',
#  'custom_window_treatments',
#  'deck',
#  'deco_brick_wall',
#  'deco_brick_walls',
#  'deco_fireplace',
#  'decorative_fireplace',
#  'decorative_wooden_fireplace',
#  'designer_finishes',
#  'diamond_no_fee_deal____massive_1br_w__home_office___condo_quality_finishes___eat_in_kitchen___1_blk_to_the_park',
#  'diamond_no_fee_deal____sprawling_sunfilled_2br_w_private_terrace___ss_kitchen___elev_lndry_bldg___3_blks_to_l_train',
#  'diamond_uws_deal____massive_studio___exposed_brick___dishwasher___pets_ok___steps_to_the_park',
#  'digital_tv',
#  'dining_area',
#  'dining_living_room',
#  'dining_room',
#  'diplomats_ok',
#  'direct_bus_line_to_ferry',
#  'dish_washer',
#  'dishwaser',
#  'dishwasher',
#  'dishwasher_microwave',
#  'diswasher',
#  'dog_okay',
#  'dogs_allowed',
#  'dogs_ok',
#  'dogs_under_20_lbs_________________parking___additional_fee',
#  'doorman',
#  'double_duplex_deal____sprawling_3br_home___1_5_baths___private_deck___balcony____eat_in_kitchen___washer__dryer___all_modern_new',
#  'double_height_lobby_french_limestone_and_rojo_alicante_marble',
#  'double_hung_wooden_shutters',
#  'double_panned_sound_proof_windows__renovated_open_kitchen_marble_and_stainless_steel_countertops',
#  'dry_cleaning_service',
#  'dryer_in_unit',
#  'duplex',
#  'duplex_layout',
#  'duplex_lounge',
#  'dw',
#  'dw__duplex___penthouse',
#  'e60s_excellence___sprawling_1br_home___gourmet_kitchen___windows_all_around___pets_ok',
#  'east_and_west_resident_lounges_reading_room_outdoor_lounges_with_river_views_party_room_chefs_kitchen_movie_screening_room_tot_spot_playroom_ping_pong',
#  'east_village',
#  'east_village_baby____oversized_2br_home___1_5_baths___eat_in_kitchen___fireplace___exposed_brick___scenic_roof_deck___lndry_bldg',
#  'east_village_extravaganza___massive_2br_home___perfect_share___cook_s_kitchen___perfect_natural_light',
#  'easy_qualification',
#  'easy_to_show',
#  'eat_in_kitchen',
#  'electric_included',
#  'electricity___hot_water___gas___heat_included',
#  'electricity_included',
#  'electronic_keycard',
#  'electronic_rent_payment',
#  'electronic_rent_payment__ach',
#  'elegant_e50s_____sprawling_sundrenched_2br_home___french_drs___breakfast_bar___dishwasher___eat_in_kitchen___walk_in_closets',
#  'elegant_e50s___park_baby____massive_4br_mansion___no_broker_fee___dishwasher___walls_of_windows___elev_bldg',
#  'elegant_east_village____massive_2br_super_share___modern___new___exposed_brick___lndry_bldg',
#  'elegant_glass_enclosed_private_lounge_with_magnificent_river_views',
#  'elevator',
#  'elevator___laundry',
#  'elevator_building',
#  'elevator_laundry__so_close_to_the_6__2450',
#  'entire_floor____enormous_4br_mega_share___magic_eraser_clean___unique_renovations___pets_ok',
#  'entire_floor____sprawling_2br_home___immaculate_renovations___fireplace___2_blks_to_bedford_l_stop',
#  'equal_king_size_bedrooms',
#  'equal_size_rooms',
#  'european_air_condition_in_each_room',
#  'everything_brand_new',
#  'exclusive',
#  'exclusive_rental',
#  'exclusive_residential_lounge___café___spacious_and_breathtaking_fully_landscaped_10',
#  'executive_conference_room_with_large_screen_hdtv',
#  'exercise_equipment__if_furnished',
#  'exercise_studio',
#  'exercise_yoga_studio',
#  'expansive_4br_duplex_dream_share___garden____huge_windows_galore___ornate_prewar_details___2_blks_to_bedford_l',
#  'expansive_king_sized_2br_mega_share___eat_in_kitchen___bike_storage___courtyard___3_blks_to_bedford_l',
#  'expansive_living_room',
#  'expansive_sundeck',
#  'exposed_brick',
#  'exposed_brick_wall',
#  'exposed_brick_walls',
#  'exposed_brickhardwood_floors_microwaverenovated_open_view_excellent',
#  'exposed_bricks',
#  'exquisite_riverside_special____stunning_studio_duplex___fireplace___gut_renovated___steps_to_the_park',
#  'extra_closet_space',
#  'extra_room',
#  'extra_storage',
#  'extra_sweet_east_village____massive_2br_home___ornate_prewar_details___exposed_brick___cook_s_kitchen___pets_ok',
#  'extravagant_east_village____massive_4br_mansion___2_full_baths___gourmet_kitchen___roomy_closets',
#  'extreme_e50s_excellence___all_modern___new___massive_1br_home___gourmet_kitchen___lndry_bldg___real_pix',
#  'eye_popping_no_fee____massive_1br_home___exposed_brick___private_terrace___dishwasher___elev_bldg___roof_deck___pets_ok',
#  'features__washer_dryer',
#  'featuring_a_sophisticated_precor__online_profile_system_that_tracks_your_personal_fitness_goals',
#  'finished_basement',
#  'fios_high_speed_internet',
#  'fire_place',
#  'fireplace',
#  'fireplace_storage',
#  'fireplaces',
#  'fitness_center',
#  'fitness_center_and_health_club',
#  'fitness_facility',
#  'fitness_room',
#  'flat_screen_tv',
#  'flat_screen_tv_and_sound_system',
#  'flex_1',
#  'flex_2',
#  'flex_3',
#  'flex_3_bed',
#  'flex_4',
#  'flex_two_bed',
#  'flexible_viewing_times',
#  'floor_to_ceiling_windows',
#  'four_barbecue_grills',
#  'foyer',
#  'free_brealfast',
#  'free_cable_tv_and_wireless_internet',
#  'free_gym',
#  'free_health_club',
#  'free_month___no_fee',
#  'free_storage',
#  'free_wifi',
#  'free_wifi_in_club_lounge',
#  'french_door',
#  'french_doors',
#  'ft_doorman',
#  'full_floor',
#  'full_kitchen',
#  'full_service_condominium',
#  'full_service_garage',
#  'full_service_luxury_highrise',
#  'full_size_gym',
#  'full_skyline_view',
#  'full_time_doorman',
#  'fully__equipped',
#  'fully_equipped_chef_s_kitchen_with_private_roof_deck',
#  'fully_equipped_club_fitness_center',
#  'fully_equipped_fitness_center_with_studio_for_classes',
#  'fully_equipped_gym',
#  'furnished',
#  'furnished_price__central_air_conditioning__high_ceilings__stainless_steel_appliances__fully_equipped_stainless_steel_appliances_kitchen',
#  'furnished_rental',
#  'furnished_wrap_around_terrace',
#  'game_center',
#  'game_room',
#  'garage',
#  'garage_attached',
#  'garage_fitness_facility_laundry_room_valet_lounge_billiards_room_rooftop_deck_wifi_access',
#  'garage_parking',
#  'garbage_disposal',
#  'garden',
#  'garden_patio',
#  'garden_roof_deck',
#  'gardening_area_with_rentable_plots',
#  'gas_and_electric_included_in_rent',
#  'gas_electric_included',
#  'gas_included',
#  'gas_stove',
#  'gatehouse_security',
#  'gigantic_greenpoint_2br_home___room_to_entertain___extra_storage___dining_room___all_brand_new',
#  'golf_simulator',
#  'gramercy',
#  'gramercy_park',
#  'grand_central',
#  'granite_bath',
#  'granite_bathroom',
#  'granite_counter',
#  'granite_counter_tops',
#  'granite_counters',
#  'granite_countertops',
#  'granite_kitchen',
#  'greal_location',
#  'great_area',
#  'great_closet_space',
#  'great_light_and_location__fresh_paint',
#  'great_location',
#  'great_natural_light',
#  'great_river_views',
#  'great_share',
#  'great_view',
#  'great_views',
#  'great_views_of_the_neighborhood',
#  'green_building',
#  'greenpoint_giant___huge_true_2br_mega_share___sparkling_clean___brite___steps_to_the_park___bedford_l_stop',
#  'greenpoint_giant___sprawling_2br_home___chef_s_kitchen___perfect_natural_light___steps_to_the_park___train',
#  'ground_floor',
#  'guarantors_accepted',
#  'guarantors_okay',
#  'guest_suite_for_residents_only',
#  'gut_renovated',
#  'gut_renovation',
#  'gut_renovations',
#  'gym',
#  'gym_discount',
#  'gym_fitness',
#  'gym_fitness_lounge_swimming_pool_sun_decks_exercise_studios_indoor_half_basketball_court',
#  'gym_in_building',
#  'half_bath',
#  'half_floor_through',
#  'hardwood',
#  'hardwood__floors',
#  'hardwood_floor',
#  'hardwood_flooring',
#  'hardwood_flooring_throughout',
#  'hardwood_floors',
#  'harwood_floors',
#  'health_club',
#  'health_club___indoor_swimming_pool',
#  'health_club_with_pool_on_the_top_floor',
#  'heart_of_the_village____massive_3br_super_share___mr_clean_approved___ornate_prewar_details___gourmet_kitchen___tons_of_sunlight',
#  'heat___water_included',
#  'heat_and_hot_water_included',
#  'heat_and_water_included_in_rent',
#  'heat_hot_water_gas_included',
#  'heat_hot_water_included',
#  'heat_included',
#  'heated_lap_pool',
#  'herringbone_wood_floors',
#  'hi_rise',
#  'high_ceil',
#  'high_ceiling',
#  'high_ceilings',
#  'high_floor',
#  'high_floor_unit',
#  'high_speed_elevator',
#  'high_speed_internet',
#  'high_speed_internet_access',
#  'high_speed_internet_available',
#  'highhhhhh_ceilings',
#  'highland_park',
#  'highrise',
#  'historical_brownstone_originally_built_in_1901',
#  'holy_deal_batman_____oversized_3br_mansion___2_full_baths___huge_scenic_terrace___doorman___elev_lndry_bldg___roof_deck___real_pix',
#  'holy_deal_batman____entire_floor____massive_4br_mansion___gourmet_kitchen___pets_ok',
#  'holy_deal_batman____sprawling_3br_home___cook_s_kitchen___2_blks_to_waterfront___bedford_l_stop',
#  'holy_no_fee____oversized_2br_home___private_terrace___scenic_roof_deck___ss_kitchen___dishwasher___elev_lndry_bldg___3_blks_to_l_train',
#  'holy_no_fee_deal____oversized_2br_super_share___private_terrace___ss_kitchen___dishwasher___elev_lndry_bldg___3_blks_to_l_train',
#  'holy_no_fee_deal_batman____massive_1br_home___chef_s_kitchen___magic_eraser_clean___pets_ok___real_pix',
#  'holy_no_fee_deal_batman____oversized_2br_home___sparkling_clean___brite___heart_of_greenpoint___near_the_park___trains',
#  'home_office',
#  'hot_water_inc__huge_walk_in_closet_or_extra_room',
#  'hot_water_included',
#  'housekeeeping',
#  'housekeeping',
#  'housekeeping___dry_cleaning_services',
#  'housekeeping_service',
#  'however_there_s_a_standing__no_walls__building_policy',
#  'huge',
#  'huge_1_bedroom',
#  'huge___gut_renovated',
#  'huge_balcony',
#  'huge_bedrooms',
#  'huge_closets',
#  'huge_living_room',
#  'huge_private_backyard',
#  'huge_room',
#  'huge_rooms',
#  'huge_true_2br_super_share___exposed_brick___gourmet_kitchen___lndry_bldg___heart_of_the_village',
#  'huge_true_2br_super_share___ornate_prewar_details___so_fresh___so_clean___l_train_baby',
#  'huge_true_3br_home___mr_clean_approved___massive_windows_galore___steps_to_the_park___bedford_l_stop',
#  'huge_true_3br_home___the_perfect_share___massive_windows_galore___cook_s_kitchen___steps_to_l_train',
#  'huge_true_3br_super_share___stunning_renovations___walls_of_windows___cook_s_kitchen___gorgeous_greenwich_village',
#  'huge_walk_in_closet',
#  'in_unit_washer___dryer',
#  'in_unit_washer_and_dryer',
#  'in_unit_washer_dryer',
#  'incredible_views',
#  'individual_climate_control',
#  'indoor_50ft_lap_pool__dishwasher__free_bike_storage',
#  'indoor_garage_available',
#  'indoor_parking',
#  'indoor_pool',
#  'indoor_swimming_pool',
#  'intercom',
#  'island_kitchen',
#  'jacuzzi',
#  'jacuzzi_bath_tube',
#  'jr_1_bed',
#  'julian_balcony',
#  'june_1st_occupancy',
#  'junior_1_bedroom_layout',
#  'just_listed',
#  'just_renovated',
#  'keyed_elevator_with_direct_access_into_your_living_room',
#  'kids_play_room',
#  'kids_playroom',
#  'king_bedrooms',
#  'king_size_bedroom',
#  'king_size_bedrooms',
#  'king_sized_bedroom',
#  'kitchen_island',
#  'kitchen_pantry',
#  'landlord_is_offering_month_of_april_free',
#  'landlord_paying_for_all_utilities__tenant_pays_for_cable___tv___internet',
#  'landmark_building',
#  'large',
#  'large___medium_storage',
#  'large_apartment',
#  'large_closets',
#  'large_finished_basement',
#  'large_living_area',
#  'large_living_room',
#  'large_living_room___bedrooms',
#  'large_livingroom',
#  'large_open_kitchen',
#  'large_patio',
#  'large_private_deck',
#  'large_private_terrace',
#  'large_room',
#  'large_rooms',
#  'large_windows',
#  'large_windows_w__lots_of_natural_light',
#  'large_windows_w__natural_light',
#  'large_windows_with_lots_of_natural_light',
#  'laundry',
#  'laundry___dry_cleaning_and_auto_care',
#  'laundry___housekeeping',
#  'laundry___housekeeping___marc_club_includes_a_cinema_room',
#  'laundry_facility_on_every_floor',
#  'laundry_hookup',
#  'laundry_in_basement',
#  'laundry_in_bldg',
#  'laundry_in_building',
#  'laundry_in_some_units',
#  'laundry_in_unit',
#  'laundry_on_every_floor',
#  'laundry_on_floor',
#  'laundry_room',
#  'laundry_room_as_well_as_housekeeping___dry_cleaning_services',
#  'laundry_room_code_is_3401',
#  'laundry_room_on_every_floor__health_club',
#  'lease_term__flexible__3_months___1_year___furnished_or_unfurnished',
#  'leed_certificate_gold',
#  'leed_certified',
#  'lex_ave_luxury____sprawling_sunfilled_1br_home___all_utilities_incl____doorman___elev_lndry_bldg___cats_ok',
#  'lexington_95th',
#  'library',
#  'light',
#  'lighting_upgrades',
#  'limited_time___no_fee',
#  'linoleum',
#  'live_in_resident_manager',
#  'live_in_super',
#  'live_in_superintendent',
#  'live_work',
#  'living_dining_room',
#  'local_gym_discount',
#  'loft',
#  'loft_area',
#  'loft_like',
#  'loft_storage',
#  'lot_s_of_light',
#  'lots_of_light',
#  'lounge',
#  'lounge_area',
#  'lounge_room',
#  'lounge_spaces',
#  'lounge_w__free_wifi',
#  'lounge_with_wifi',
#  'low_fee',
#  'low_fee_and_great_space_too',
#  'low_fee_listing',
#  'low_rise',
#  'lowrise',
#  'luxury_building',
#  'madison_square_park',
#  'magnificent_venetian_style',
#  'mail_room',
#  'manhattan_views',
#  'marble_bath',
#  'marble_bathroom',
#  'marble_bathrooms',
#  'market_on_site',
#  'marvelous_midtown_gem___spacious_sundrenched_studio___stunning_prewar_details___cats_ok',
#  'massive_1br_home___rent_stabilized___separate_kitchen___walls_of_windows___roomy_closets',
#  'massive_3br_super_share___washer_dryer___ornate_prewar_details___steps_to_bedford_l_stop',
#  'massive_home',
#  'massive_living_room',
#  'masterful_3br_mansion___the_perfect_share___backyard___eat_in_kitchen___1_blk_to_bedford_l',
#  'masterful_bkln_mansion____sprawling_3br_home___ornate_prewar_details___gourmet_kitchen___1_blk_to_bedford_l',
#  'masterful_bklyn_find____sprawling_3br_mega_share___gourmet_kitchen___mr_clean_approved___2_blks_to_bedford_l',
#  'media_room',
#  'media_screening_room',
#  'microwave',
#  'mid_rise',
#  'midrise',
#  'midtown_east_elegance____massive_1br_home___walls_of_windows___gourmet_kitchen___brand_spankin__new',
#  'midtown_mansion___huge_2br_home___eat_in_kitchen___ss_appl___french_doors___roomy_closets',
#  'midtown_mansion___sprawling_sunfilled_studio___utilities_included___doorman___elev_lndry_bldg___pets_ok',
#  'midtown_marvel____massive_1br_home___gourmet_kitchen___unique_prewar_details___roomy_closets___all_new',
#  'midtown_miracle___sprawling_1br_home___cook_s_kitchen___windows_all_around___roomy_closets',
#  'midtown_miracle___sprawling_2br_super_share___ss_eat_in_kitchen___french_doors___ornate_prewar_details',
#  'midtown_no_fee_mansion____sprawling_2br_super_share___chef_inspired_kitchen___elev_lndry_bldg',
#  'mins_from_train',
#  'mint',
#  'mint_condition',
#  'misting_shower_and_resident_lounge_available',
#  'modern_finishes',
#  'modern_kitchen',
#  'modern_marvel____heart_of_the_village___oversized_2br_home___exposed_brick___lndry_bldg',
#  'modern_village_marvel___sprawling_2br_home___exposed_brick___lndry_bldg___near_the_park',
#  'month_free',
#  'mosaic_tiled_kitchen',
#  'move_in_coordination',
#  'movie_theater',
#  'mullion_pane_windows',
#  'multi_level',
#  'multi_level_mansion___huge_4br_duplex___mr_clean_approved___oversized_windows_galore___2_blks_to_bedford_l_stop',
#  'murray_hill_no_fee_mansion___sprawling_1br_home___ornate_prewar_details___gourmet_kitchen___windows_all_around',
#  'must_see',
#  'mw',
#  'natural_light',
#  'natural_sunlight',
#  'near_all_trains',
#  'near_nqrmg_trains',
#  'near_pratt',
#  'near_subway',
#  'near_transportation',
#  'nearby_m___r_trains',
#  'nearby_medical_centers',
#  'new',
#  'new_appliances',
#  'new_construction',
#  'new_electric',
#  'new_flooring',
#  'new_kitchen',
#  'new_marble_bathroom',
#  'new_reno',
#  'new_renovation',
#  'new_stainless_appliances',
#  'new_stainless_steel_appliances',
#  'newly_renovated',
#  'newly_renovated_large_bright',
#  'newly_renovated_w__oak_wood_floors___mid_century_modern_style_interior___large_closets_in_every_bedroom_extra_storage_space_in_hall__large_living_room',
#  'nmw',
#  'no_alternate_side_parking_rules_in_neighborhood',
#  'no_application_fee',
#  'no_board_approval',
#  'no_broker_fee',
#  'no_broker_fee____massive_2br_super_share___eat_in_kitchen___private_terrace___elev_lndry_bldg___1_blk_to_l_train',
#  'no_broker_fee__no_fee',
#  'no_broker_s_fees',
#  'no_fee',
#  'no_fee___luxury_doorman_building___river_views',
#  'no_fee___roof_deck',
#  'no_fee_baby____massive_2br_w_terrace___gourmet_ss_kitchen___elev_lndry_bldg___scenic_roof_deck___3_blks_to_train',
#  'no_fee_bkln_luxury____expansive_1br_w_home_office___eat_in_kitchen___full_renovated___1_blk_to_the_park___steps_to_l_train',
#  'no_fee_hardwood_floors',
#  'no_fee_multi_level_mansion____massive_3br_triplex___huge_private_terrace___e50s___park_ave___elev_lndry_bldg',
#  'no_fee_or_one_month_free',
#  'no_fee_specialist__harry_ego_718_413_8270_hego_citihabitats_com',
#  'no_pets',
#  'null',
#  'nyu',
#  'oak_cabinets',
#  'oak_floors',
#  'offering__1_month_free_or_1_month_op',
#  'on_site_atm_machine',
#  'on_site_attended_garage',
#  'on_site_dog_park_and_pet_spa',
#  'on_site_garage',
#  'on_site_laundry',
#  'on_site_lifestyle_concierge_by_luxury_attaché',
#  'on_site_lifestyle_concierge_by_luxury_attaché__24_7_doorman___state_of_the_art_cardiovascular_and_weight_training_equipment___24_hour_valet_parking_garage___valet_services_including_dry_cleaning',
#  'on_site_management',
#  'on_site_parking',
#  'on_site_parking_available',
#  'on_site_parking_garage',
#  'on_site_parking_lot',
#  'on_site_resident_manager',
#  'on_site_super',
#  'on_sites_super',
#  'one_flight_walk_up',
#  'one_month_fee',
#  'one_month_free',
#  'one_month_free_rent',
#  'one_month_rent_free_concession_on_a_12_month_lease',
#  'one_of_a_kind_no_fee____massive_3br_mansion___eat_in_kitchen___tons_of_sunlight___2_blks_to_train',
#  'one_small_dog_ok_on_approval',
#  'only_1st_and_security__heat_and_hot_water_included__no_fee__732_330_4737',
#  'only__250_deposit_with_approved_credit',
#  'onsite_dry_cleaner',
#  'onsite_super',
#  'onsite_super_and_porter',
#  'onsite_valet',
#  'open_concept_kitchen',
#  'open_granite_kitchen',
#  'open_house_sat__may_14_12__1pm',
#  'open_kitchen',
#  'open_layout',
#  'open_views',
#  'original_details',
#  'original_molding_details',
#  'outdoor_areas',
#  'outdoor_basketball_court',
#  'outdoor_bbqs',
#  'outdoor_entertainment_space',
#  'outdoor_grilling_terrace',
#  'outdoor_play_area',
#  'outdoor_pool',
#  'outdoor_roof_deck_overlooking_new_york_harbor_and_battery_park',
#  'outdoor_space',
#  'outdoor_space__private_roof_deck',
#  'outdoor_terrace',
#  'outstanding_shopping',
#  'over_sized_apartment',
#  'over_sized_windows',
#  'overlooks_garden',
#  'oversize_terrace',
#  'oversized',
#  'oversized_1br_duplex_dream___mr_clean_approved___unique_details___near_central_park___w50s_baby___pets_ok',
#  'oversized_1br_home___gut_renovated___perfect_natural_light___heart_of_chelsea___pets_ok',
#  'oversized_1br_home___huge_windows_galore___washer_dryer___rent_stabilized____off_6th_ave___heart_of_midtown',
#  'oversized_2br_super_share___chef_s_kitchen___exposed_brick___lndry_bldg___heart_of_the_village',
#  'oversized_2br_super_share___french_doors___ss_eat_in_kitchen___mr_clean_approved___heart_of_midtown',
#  'oversized_3br_home___sparkling_clean___tons_of_natural_light___2_blks_to_the_waterfront___bedford_l_stop',
#  'oversized_3br_super_share___equal_sized_brs____wall_of_windows___washer_dryer___steps_to_bedford_l_stop',
#  'oversized___underpriced_____sprawling_sunfilled_studio___gourmet_kitchen___gut_renovated___w50s___near_central_park',
#  'oversized___underpriced____sprawling_conv_3br_mansion___massive_windows_galore___elev_bldg___steps_to_the_park',
#  'oversized___underpriced____sprawling_sunfilled_studio___roomy_closets___tons_of_sunlight___pets_ok',
#  'oversized___underpriced___classy_corner_studio___all_modern___new___perfect_sunlight___pets_ok',
#  'oversized___underpriced_no_fee___huge_2br_home___all_modern___new___eat_in_kitchen___2_blks_to_the_train',
#  'oversized___underpriced_no_fee___sprawling_3br_super_share___separate_cook_s_kitchen___walls_of_windows___2_blks_to_train',
#  'oversized_closet',
#  'oversized_shower_tub',
#  'oversized_window',
#  'oversized_windows',
#  'own_entrance',
#  'owner_occupied___3_family_townhouse___no_realtor_fees___this_beautiful_apt_is_offered_below_market_rate',
#  'package___grocery_delivery_storage',
#  'package_receiving',
#  'package_room',
#  'package_service',
#  'park_block',
#  'park_view',
#  'parking',
#  'parking_available',
#  'parking_garage',
#  'parking_space',
#  'parking_spot_with_additional_fee',
#  'parks_in_area',
#  'parquet_floors',
#  'part_time_doorman',
#  'partially_furnished_with_two__2__air_conditioners_and_microwave_unit',
#  'party_meeting_room',
#  'party_room',
#  'patio',
#  'penthouse',
#  'perfect_location',
#  'personal_trainer',
#  'pet_friendly',
#  'pet_friendly___case_by_case',
#  'pet_grooming_room',
#  'pets',
#  'pets___case_by_case',
#  'pets__case_by_case',
#  'pets__cats_only',
#  'pets__cats_small_dogs',
#  'pets_allowed',
#  'pets_allowed_case_by_case',
#  'pets_ok',
#  'pets_on_approval',
#  'pets_upon_approval',
#  'pets_welcome',
#  'photos_of_actual_apartment',
#  'pilates_and_training_room',
#  'playroom',
#  'playroom_nursery',
#  'plus_1_month_free',
#  'poker_table',
#  'polished_hardwood_floors',
#  'poo',
#  'pool',
#  'post_war',
#  'postwar',
#  'pre_war',
#  'pre_war_brand_new_renovations',
#  'pre_war_charm',
#  'pre_war_details',
#  'pre_war_small_dogs',
#  'premier_resident_services_offered_by_our_friendly_and_helpful_staff',
#  'previous_tenant_found_easy_on_street_parking',
#  'prewar',
#  'prime_location',
#  'pristine_modern_townhouse____massive_2br_home___chef_inspired_kitchen___huge_windows_galore___cats_ok',
#  'pristine_park_ave_find____massive_2br_triplex_dream_share___dining_rm___elev_lndry_bldg___heart_of_the_e50s',
#  'pristine_park_ave_s_loft____massive_3br_mansion___walls_of_windows___chef_inspired_kitchen___elev_bldg',
#  'pristine_prewar_gem____massive_3br_super_share___gut_renovated___chef_s_kitchen___elev_bldg___pets_ok',
#  'pristine_townhouse___massive_2br_super_share___dishwasher___e50s_baby____perfect_natural_light___roomy_closets',
#  'private_backyard',
#  'private_balcony',
#  'private_deck',
#  'private_dining_room',
#  'private_entrance',
#  'private_entrances',
#  'private_fenced_yard',
#  'private_garage_available',
#  'private_garden',
#  'private_laundry_room_on_every_floor',
#  'private_lounge_w__wet_bar___billiards_table',
#  'private_outdoor_garden',
#  'private_outdoor_space',
#  'private_parking',
#  'private_patio',
#  'private_roof_access',
#  'private_roof_deck',
#  'private_roofdeck',
#  'private_shuttle',
#  'private_storage',
#  'private_terrace',
#  'publicoutdoor',
#  'queen___king_size_bedrooms',
#  'queen_bedrooms',
#  'queen_size_bedrooms',
#  'queen_size_sleeping_alcove',
#  'queen_sized_bedroom',
#  'queen_sized_bedrooms',
#  'queen_sized_rooms',
#  'quiet',
#  'quiet_neighborhood',
#  'rare_find____huge_true_2br___courtyard___fully_renovated___eat_in_kitchen___2_blks_to_bedford_l',
#  'rare_find____huge_true_2br_super_share___chef_s_kitchen___courtyard____2_blks_to_bedford_l_stop',
#  'rare_find____sprawling_sundrenched_1br_home___stunning_finishes___ss_kitchen___washer_dryer___dishwasher___heart_of_chelsea',
#  'rare_find___unique_carriage_house___massive_true_2br___private_garden___washer_dryer___2_blks_to_l_train',
#  'real_no_fee____massive_true_2br_super_share___all_modern___new___eat_in_kitchen___2_blks_to_the_train',
#  'real_no_fee_baby____expansive_3br_masterpiece___spacious___sunfilled___sparkling_clean___eat_in_kitchen___2_blks_to_train',
#  'real_no_fee_luxury____oversized_2br_home___fit_for_queens______chef_s_kitchen___walls_of_windows___1_blk_to_train',
#  'real_sand_beach_volleyball_courts',
#  'real_wall_allowed',
#  'recent_renovation',
#  'recently_renovated',
#  'recessed_lighting',
#  'recessed_lights',
#  'recreational_room',
#  'reduced_fee',
#  'reduced_fee_while_it_lasts',
#  'redwood_hardwood_floor',
#  'refrigerated_storage_in_lobby_for_grocery_deliveries',
#  'renovated',
#  'renovated_1_bed',
#  'renovated_apt',
#  'renovated_bathroom',
#  'renovated_kitchen',
#  'rent_includes_cable_tv_and_wireless_internet',
#  'rent_is_net_effective_gross_price_is__3250',
#  'rent_stabalized',
#  'rent_stabilize',
#  'rent_stabilize___elevator_building',
#  'rent_stabilized',
#  'rent_stabilized______rare',
#  'rent_stabilized___oversized_1br_home___mr_clean_approved___separate_cook_s_kitchen___heart_of_midtown',
#  'rentable',
#  'resident_events',
#  'resident_s_courtyard',
#  'resident_super_in_the_building',
#  'residents__lounge',
#  'residents_can_choose_from_three_high_speed_internet_providers__verizon_fios',
#  'residents_garden',
#  'residents_lounge',
#  'residents_only_fitness_center_and_aerobic_room_professionally_outfitted_with_a_full_complement_of_strength_and_cardio_training_equipment',
#  'restaurant',
#  'right_on_lexington_ave___close_to_subway',
#  'river_view',
#  'river_views',
#  'riverside_no_fee_special____sprawling_1br_home___fireplace___bay_windows___exposed_brick___dishwasher___lndry_bldg',
#  'roof',
#  'roof_access',
#  'roof_deck',
#  'roof_deck_with_grills',
#  'roof_deck_with_real_grass',
#  'roof_deck_with_stunning_view',
#  'roof_garden_and_lounge',
#  'roof_grilling_area',
#  'roof_sundeck',
#  'roofdeck',
#  'rooftop',
#  'rooftop_access',
#  'rooftop_deck',
#  'rooftop_sundeck',
#  'rooftop_terrace',
#  'rooftop_with_grills',
#  's_s_appliances',
#  's_steel_appliances',
#  'sassy_soho_steal____no_fee____sprawling_studio_home___gourmet_kitchen___huge_closets___elev_bldg',
#  'satellite_tv',
#  'sauna',
#  'screening_room',
#  'security_______available_june_1st',
#  'semi_private_backyard',
#  'separate_entryway',
#  'separate_kitchen',
#  'seperate_kitchen',
#  'share_ok',
#  'shared_backyard',
#  'shared_garden',
#  'shared_yard',
#  'shares_ok',
#  'shares_okay',
#  'short_term',
#  'short_term_allowed',
#  'shuttle_service',
#  'shuttle_service_to_subway',
#  'shuttle_to_7_train',
#  'simplex',
#  ...]

# %%
# Out:
# 1649
# ['000',
#  '000_sf_fitness_center',
#  '000_sq',
#  '000_square_foot_exclusive_courtyard_oasis_for_via_residents',
#  '01',
#  '04',
#  '0862',
#  '1000',
#  '1100_sq_ft',
#  '1200sq_ft',
#  '12_month_leases_allowed',
#  '12th_st_',
#  '15',
#  '1500',
#  '16',
#  '16______swimming_pool_________dishwasher',
#  '16_____firepalce',
#  '16____dishwasher',
#  '1_bed',
#  '1_br_or_conv_2',
#  '1_mo_broker',
#  '1_month_free',
#  '1_month_free_rent',
#  '1ba',
#  '1st',
#  '22',
#  '24',
#  '2450',
#  '24_hour_attended_lobby',
#  '24_hour_doorman',
#  '24_hour_doorman_concierge',
#  '24_hr_concierge',
#  '24_hr_doorman',
#  '24hr_doorman',
#  '24hr_doormen',
#  '24hr_white',
#  '24th_st_',
#  '250_application_fee_with_background_and_credit_check',
#  '250_deposit_with_approved_credit',
#  '250_security_deposit',
#  '25lb_weight_limit_on_pet',
#  '2_bath',
#  '2_bathrooms',
#  '2_beautifully_furnished_outside_sundecks',
#  '2_bedroon_convertible',
#  '2_blk_to_bedford_l_',
#  '2_block_away',
#  '2_blocks_away_from_union_square',
#  '2_full_bathrooms',
#  '2_full_baths',
#  '2_month_fee',
#  '2_months_free',
#  '2_queen_bedrooms',
#  '2_story_tenant_lounge',
#  '2_year_lease',
#  '2nd',
#  '2nd_ave',
#  '30',
#  '30th_',
#  '30th_st_',
#  '3250',
#  '330',
#  '36th_st_',
#  '373',
#  '3_ac',
#  '3_bath',
#  '3br',
#  '413',
#  '4737',
#  '4_roof',
#  '4_train_is_less_than_1_block_away',
#  '4th_floor_walk_up',
#  '4th_off_charles',
#  '500_security_deposit',
#  '500_sq_ft',
#  '50_ft',
#  '55th_',
#  '5_bath',
#  '5_bathrooms',
#  '5_baths',
#  '5_baths_',
#  '5_bed',
#  '5_marble_baths',
#  '600_gift_card_for_move',
#  '65th',
#  '6_bedrooms',
#  '700_sf',
#  '732',
#  '73rd_st',
#  '75th_',
#  '78th_',
#  '79th',
#  '7_concierge',
#  '7_doorman',
#  '7_doorman_',
#  '7_doorman_concierge',
#  '7_fitness_center',
#  '7_full',
#  '81st_',
#  '8270_hego',
#  '87th_',
#  '9th_floor_manhattan_views',
#  '_1',
#  '_1_blk_to_bedford_l_',
#  '_1_blk_to_bedford_l_stop_',
#  '_1_blk_to_l_train_',
#  '_1_blk_to_the_park_',
#  '_1_blk_to_train_',
#  '_1_year_',
#  '_1pm',
#  '_1st',
#  '_24',
#  '_2_blks_to_bedford_l_',
#  '_2_blks_to_bedford_l_stop_',
#  '_2_blks_to_l_train_',
#  '_2_blks_to_the_train_',
#  '_2_blks_to_the_waterfront_',
#  '_2_blks_to_train_',
#  '_2_blks_to_waterfront_',
#  '_2_full_baths_',
#  '_3_bedroom',
#  '_3_blks_to_bedford_l_',
#  '_3_blks_to_l_train_',
#  '_3_blks_to_train_',
#  '_3_family_townhouse_',
#  '_3_months_',
#  '_3lg_closets',
#  '_3rd_ave',
#  '_4_blks_to_bedford_l_',
#  '_6th_ave',
#  '_917',
#  '________________parking_',
#  '__chef',
#  '_a',
#  '_additional_fee',
#  '_air_conditioners_and_microwave_unit',
#  '_all_brand_new',
#  '_all_brand_new_',
#  '_all_brand_new_no_fee',
#  '_all_modern_',
#  '_all_modern_new',
#  '_all_new',
#  '_all_new_',
#  '_all_utilities_incl',
#  '_amazing_corner_layout_',
#  '_and_much_more',
#  '_atm_machine_on',
#  '_backyard_',
#  '_balconies',
#  '_balcony',
#  '_bay_windows_',
#  '_bedford_l_stop_',
#  '_bedrooms',
#  '_bike_storage_',
#  '_billiards_table',
#  '_bklyn',
#  '_board_interview_and_approval',
#  '_brand_spankin',
#  '_breakfast_bar_',
#  '_bright_',
#  '_bring_ur_bbq',
#  '_brite_',
#  '_brownstone_beauty_',
#  '_building_policy',
#  '_café_',
#  '_case_by_case',
#  '_case_by_case_',
#  '_cats',
#  '_cats_ok_',
#  '_cats_only',
#  '_central_air_conditioning',
#  '_central_park_steal',
#  '_chef',
#  '_chef_inspired_eat',
#  '_chef_inspired_kitchen_',
#  '_chelsea_baby',
#  '_chic_chelsea_find',
#  '_chic_chelsea_locale',
#  '_chic_chelsea_steal',
#  '_classy_clinton_home_',
#  '_classy_condo_gem',
#  '_classy_conv_2br_duplex_dream',
#  '_classy_corner_studio_',
#  '_classy_corner_studio_supreme_',
#  '_clean_',
#  '_close_to_subway',
#  '_columbia_',
#  '_condo_quality_finishes_',
#  '_cook',
#  '_court_square_gem',
#  '_courtyard',
#  '_courtyard_',
#  '_cpw',
#  '_custom_finishes_',
#  '_dance_studio',
#  '_diamond_no_fee_deal',
#  '_diamond_uws_deal',
#  '_dining_rm_',
#  '_dining_room_',
#  '_dishwasher',
#  '_dishwasher_',
#  '_doorman_',
#  '_double_duplex_deal',
#  '_dry',
#  '_dry_cleaning_services',
#  '_dryer',
#  '_dryer_hookups',
#  '_dryer_in_unit',
#  '_e50s_',
#  '_e50s_baby',
#  '_e60s_excellence_',
#  '_east_village_baby',
#  '_east_village_extravaganza_',
#  '_eat',
#  '_elegant_e50s',
#  '_elegant_e50s_',
#  '_elegant_e60s',
#  '_elegant_east_village',
#  '_elev',
#  '_elev_',
#  '_elev_bldg_',
#  '_elev_that_opens_into_apt_',
#  '_elevator_building',
#  '_enormous_4br_mega',
#  '_entire_floor',
#  '_equal_sized_brs',
#  '_exercise_pool_and_whirlpool_with_lifeguard_on_duty',
#  '_expansive_1br_w',
#  '_expansive_2br_mcmansion_',
#  '_expansive_3br_masterpiece_',
#  '_expansive_4br_duplex_dream_share_',
#  '_expansive_king',
#  '_expansive_studio_steal',
#  '_exposed_brick_',
#  '_exquisite_riverside_special',
#  '_extra_storage_',
#  '_extra_sweet_east_village',
#  '_extravagant_east_village',
#  '_extreme_e50s_excellence_',
#  '_eye_popping_no_fee',
#  '_fireplace_',
#  '_fireplaces_',
#  '_fit_for_kings',
#  '_fit_for_queens',
#  '_fitness_center',
#  '_free_bike_storage',
#  '_free_gym_',
#  '_free_wifi',
#  '_free_wifi_in_marc_club',
#  '_french_doors_',
#  '_french_drs_',
#  '_fresh_paint',
#  '_ft',
#  '_full_renovated_',
#  '_fully_equipped_stainless_steel_appliances_kitchen',
#  '_fully_renovated_',
#  '_furnished_or_unfurnished',
#  '_g',
#  '_garden',
#  '_gas_',
#  '_gigantic_greenpoint_2br_home_',
#  '_gorgeous_greenwich_village_',
#  '_gourmet_chef',
#  '_gourmet_kitchen_',
#  '_gourmet_ss_kitchen_',
#  '_greenpoint_giant_',
#  '_grocery_delivery_storage',
#  '_gut_renovated',
#  '_gut_renovated_',
#  '_harry_ego_718',
#  '_health_club',
#  '_heart_of_chelsea',
#  '_heart_of_chelsea_',
#  '_heart_of_desirable_soho_',
#  '_heart_of_greenpoint_',
#  '_heart_of_midtown',
#  '_heart_of_midtown_',
#  '_heart_of_the_e50s_',
#  '_heart_of_the_village',
#  '_heart_of_the_village_',
#  '_heart_of_west_village',
#  '_heat_included',
#  '_hi_end_renovations_',
#  '_high_ceilings',
#  '_holy_deal_batman',
#  '_holy_no_fee',
#  '_holy_no_fee_deal',
#  '_holy_no_fee_deal_batman',
#  '_home_office_',
#  '_hot_water_',
#  '_housekeeping',
#  '_housekeeping_',
#  '_huge_2br_home_',
#  '_huge_4br_duplex_',
#  '_huge_closets_',
#  '_huge_private_terrace_',
#  '_huge_rear_terrace_',
#  '_huge_scenic_terrace_',
#  '_huge_true_2br_',
#  '_huge_true_2br_mega',
#  '_huge_true_2br_super_share_',
#  '_huge_true_3br_home_',
#  '_huge_true_3br_super_share_',
#  '_huge_walk',
#  '_huge_windows_galore_',
#  '_immaculate_renovations_',
#  '_indoor_swimming_pool',
#  '_internet',
#  '_key_track_for_tenants_convenience',
#  '_king_size_bedrooms',
#  '_l_train_baby',
#  '_landscaped_terrace_complete_with_an_organic_garden',
#  '_large_living_room',
#  '_laundry',
#  '_lex_ave_luxury',
#  '_lexington_ave',
#  '_lic_luxury_2br_home_',
#  '_lndry_bldg_',
#  '_location',
#  '_lots_of_natural_light',
#  '_lounge',
#  '_madison_avenue',
#  '_magic_eraser_clean_',
#  '_marc_club_includes_a_cinema_room',
#  '_marvelous_midtown_gem_',
#  '_massive_1br_',
#  '_massive_1br_home_',
#  '_massive_1br_w',
#  '_massive_2br_home_',
#  '_massive_2br_super_share_',
#  '_massive_2br_triplex_dream_share_',
#  '_massive_2br_w',
#  '_massive_3br_home_',
#  '_massive_3br_mansion_',
#  '_massive_3br_super_share_',
#  '_massive_3br_triplex_',
#  '_massive_4br_home_',
#  '_massive_4br_mansion_',
#  '_massive_studio_',
#  '_massive_studio_supreme_',
#  '_massive_true_2br_',
#  '_massive_true_2br_super_share_',
#  '_massive_windows_galore_',
#  '_masterful_3br_mansion_',
#  '_masterful_bkln_mansion',
#  '_masterful_bklyn_find',
#  '_may_14_12',
#  '_medium_storage',
#  '_midtown_east_elegance',
#  '_midtown_mansion_',
#  '_midtown_marvel',
#  '_midtown_miracle_',
#  '_midtown_no_fee_mansion',
#  '_modern_',
#  '_modern_everything_',
#  '_modern_marvel',
#  '_modern_renovations_',
#  '_modern_village_marvel_',
#  '_move',
#  '_mr_clean_approved_',
#  '_multi',
#  '_murray_hill_no_fee_mansion_',
#  '_natural_light',
#  '_near_central_park',
#  '_near_central_park_',
#  '_near_columbia_u_',
#  '_near_the_park',
#  '_near_the_park_',
#  '_near_waterfront',
#  '_new',
#  '_new_',
#  '_no',
#  '_no_broker_fee',
#  '_no_broker_fee_',
#  '_no_fee',
#  '_no_fee_',
#  '_no_fee_baby',
#  '_no_fee_bkln_luxury',
#  '_no_fee_multi',
#  '_no_realtor_fees_',
#  '_oak_wood_floors___mid_century_modern_style_interior___large_closets_in_every_bedroom_extra_storage_space_in_hall',
#  '_off_6th_ave_',
#  '_on',
#  '_on_lexington_ave',
#  '_one_of_a_kind_no_fee',
#  '_online_profile_system_that_tracks_your_personal_fitness_goals',
#  '_ornate_prewar_details_',
#  '_oversized_',
#  '_oversized_1br_duplex_dream_',
#  '_oversized_1br_home_',
#  '_oversized_2br_home_',
#  '_oversized_2br_super_share_',
#  '_oversized_3br_duplex_mansion_',
#  '_oversized_3br_home_',
#  '_oversized_3br_mansion_',
#  '_oversized_3br_super_share_',
#  '_oversized_closets_',
#  '_oversized_windows_galore_',
#  '_overszed_studio_steal_',
#  '_painted_my_a_local_artist',
#  '_park_ave_',
#  '_park_baby',
#  '_pay_for_your_own_heat_with_your_own_thermostat',
#  '_perfect_natural_light_',
#  '_perfect_share_',
#  '_perfect_sun_',
#  '_perfect_sunlight_',
#  '_pets_ok_',
#  '_photos',
#  '_pristine_modern_townhouse',
#  '_pristine_park_ave_find',
#  '_pristine_park_ave_s_loft',
#  '_pristine_prewar_gem',
#  '_pristine_townhouse_',
#  '_private_backyard_',
#  '_private_deck_',
#  '_private_garden_',
#  '_private_roof_deck_',
#  '_private_terrace_',
#  '_r_trains',
#  '_rare_',
#  '_rare_find',
#  '_rare_find_',
#  '_real_no_fee',
#  '_real_no_fee_baby',
#  '_real_no_fee_luxury',
#  '_real_pix_',
#  '_renovated',
#  '_rent_stabilized',
#  '_rent_stabilized_',
#  '_riverside_no_fee_special',
#  '_roof_deck_',
#  '_room_to_entertain_',
#  '_roomy_closets_',
#  '_sassy_soho_steal',
#  '_scenic_roof_deck_',
#  '_separate_cook',
#  '_separate_kitchen_',
#  '_so_clean_',
#  '_so_close_to_the_6_',
#  '_so_fresh_',
#  '_spacious_',
#  '_spacious_and_breathtaking_fully_landscaped_10',
#  '_spacious_studio_supreme_',
#  '_spacious_sundrenched_studio_',
#  '_spacious_sunspanked_layout_',
#  '_sparkling_clean_',
#  '_sprawling_1br_home_',
#  '_sprawling_1br_w',
#  '_sprawling_2br_home_',
#  '_sprawling_2br_super_share_',
#  '_sprawling_3br_home_',
#  '_sprawling_3br_mega',
#  '_sprawling_3br_super_share_',
#  '_sprawling_conv_3br_mansion_',
#  '_sprawling_studio_home_',
#  '_sprawling_sundrenched_1br_home_',
#  '_sprawling_sundrenched_2br_home_',
#  '_sprawling_sundrenched_studio_',
#  '_sprawling_sunfilled_1br_home_',
#  '_sprawling_sunfilled_2br_w',
#  '_sprawling_sunfilled_3br_home_',
#  '_sprawling_sunfilled_4br_mansion_',
#  '_sprawling_sunfilled_studio_',
#  '_sprawling_true_2br_home_',
#  '_sprawling_true_2br_super_share_',
#  '_sprawling_true_3br_super_share_',
#  '_ss_appl_',
#  '_ss_eat',
#  '_ss_kitchen_',
#  '_ss_kitchen_w',
#  '_stainless_steel_appliances',
#  '_state_of_the_art_cardiovascular_and_weight_training_equipment_',
#  '_steps_to_bedford_l_stop_',
#  '_steps_to_central_park',
#  '_steps_to_l_train_',
#  '_steps_to_the_park',
#  '_steps_to_the_park_',
#  '_steps_to_the_waterfront_',
#  '_stroller_storage',
#  '_stunning_finishes_',
#  '_stunning_prewar_details_',
#  '_stunning_renovations_',
#  '_stunning_studio_duplex_',
#  '_sundrenched_',
#  '_sunfilled_',
#  '_sunny',
#  '_super_sexy_2br_',
#  '_super_sweet_1br_home_',
#  '_super_sweet_no_fee',
#  '_super_sweet_studio_',
#  '_tenant_pays_for_cable_',
#  '_the_perfect_share',
#  '_the_perfect_share_',
#  '_this_beautiful_apt_is_offered_below_market_rate',
#  '_tons_of_natural_light',
#  '_tons_of_natural_light_',
#  '_tons_of_storage_',
#  '_tons_of_sunlight_',
#  '_train',
#  '_trains_',
#  '_tv_',
#  '_underpriced',
#  '_underpriced_',
#  '_underpriced_no_fee_',
#  '_unique_carriage_house_',
#  '_unique_details_',
#  '_unique_find',
#  '_unique_prewar_details_',
#  '_unique_renovations_',
#  '_unique_union_sq_steal_',
#  '_unknown_type',
#  '_uptown',
#  '_utilities_included_',
#  '_valet_services_including_dry_cleaning',
#  '_verizon_fios',
#  '_w50s_',
#  '_w50s_baby_',
#  '_w50s_wonder',
#  '_w60s_wonder_',
#  '_w70s_winner',
#  '_walk',
#  '_wall_of_windows_',
#  '_walls_of_windows_',
#  '_washer',
#  '_water_included',
#  '_western_exposure',
#  '_wet_bar_',
#  '_wicked_w50s_find',
#  '_wicked_w50s_steal',
#  '_wicked_w50s_winner',
#  '_windows_al_around_',
#  '_windows_all_around_',
#  '_xl_3br_mansion_',
#  'a_full_service_luxury_highrise',
#  'a_full_service_luxury_residence',
#  'a_one',
#  'a_true_top_luxury_hi',
#  'a_wide_array_of_complimentary_fitness_classes_offered_weekly',
#  'absolute_value_for_size_',
#  'abundant_closets',
#  'ac',
#  'ac_central',
#  'accepts_credit_cards_',
#  'ach',
#  'ached_doorways',
#  'act_fast_will_not_last',
#  'act_fast_wont_last',
#  'actual_apt',
#  'actual_photos',
#  'air_condition',
#  'air_conditioned',
#  'air_conditioned_laundry_facility',
#  'air_conditioning',
#  'alcove',
#  'alcove_studio',
#  'all_common_areas_feature_wi',
#  'all_kitchen_appliances_included',
#  'all_new',
#  'all_pets_ok',
#  'all_utilities_included',
#  'amazing_deal',
#  'amazing_detail',
#  'ample_closet_space',
#  'ample_sofa_bed_in_living_space_for_extra_accommodations',
#  'an_expansive_landscaped_terrace_and_sun_deck',
#  'and_breathtaking_views_of_new_york_city_from_our_rooftop_terrace',
#  'and_rcn',
#  'and_stainless_steel_appliances_with_a_dishwasher_well_maintained_hardwood_floors_add_to_the_warmth_and_modern_feel_of_the_space',
#  'approved_animals_only',
#  'arched_doorways',
#  'area_in_front_of_bathroom',
#  'arguably_the_most_well',
#  'art_cardio_and_fitness_club',
#  'art_fitness_center',
#  'art_fitness_center_and_even_an_on',
#  'art_swimming_pool',
#  'assigned',
#  'at_an_additional_cost',
#  'atm',
#  'attached_garage',
#  'attached_parking',
#  'attached_parking_garage',
#  'attended_garage',
#  'attended_garage_and_service_entrance',
#  'attended_lobby',
#  'available_05',
#  'available_06',
#  'available__04',
#  'available__05',
#  'available__07',
#  'available_june_1st',
#  'b_billiards_table',
#  'backyard',
#  'balconies_in_both_bedrooms',
#  'balcony',
#  'balocny',
#  'baruch',
#  'basement_storage',
#  'basketball_court',
#  'bay_windows',
#  'bbq_grill',
#  'bbqs',
#  'beamed_ceilings',
#  'bicycle_and_tenant_st',
#  'bicycle_room',
#  'bicycle_room_and_individual_resident_storage',
#  'bicycle_storage',
#  'big_2_bed_deal',
#  'big_closets',
#  'big_open_spaces',
#  'big_rooms',
#  'bike_',
#  'bike_room',
#  'bike_storage',
#  'billiards_and_shuffle_board_game_room_poker_room_golf_simulator_and_putting_green',
#  'billiards_lounge',
#  'billiards_room',
#  'billiards_table_and_wet_bar',
#  'bluetooth',
#  'bluetooth_system',
#  'boating_hardwood_floors',
#  'brand_new',
#  'brand_new_appliances',
#  'brand_new_renovation',
#  'brand_new_ss_appliances',
#  'brand_new_ss_kitchen',
#  'brand_new_stainless_steal_appliances',
#  'brand_new_stainless_steel_appliances',
#  'brand_new_washer_',
#  'brand_newm_outdoor_deck',
#  'brand_spanking_new',
#  'breakfast_bar',
#  'bridge_view',
#  'bright',
#  'bright_',
#  'bright_spacious_2_br',
#  'broker_fee',
#  'brownstone',
#  'build',
#  'building',
#  'building_link_notification_',
#  'building_storage',
#  'built',
#  'built_in_ac',
#  'built_in_microwave',
#  'built_in_office_area',
#  'built_in_storage',
#  'burning_fireplace',
#  'business_center',
#  'c_',
#  'c_units',
#  'cable',
#  'cable_ready',
#  'call_timur_for_instant_access_646_847_8588',
#  'catering_facility',
#  'cats_allowed',
#  'cats_on_approval',
#  'ceiling',
#  'ceiling_fan',
#  'ceiling_fans',
#  'ceiling_windows',
#  'central_a',
#  'central_ac',
#  'central_air',
#  'central_air_conditioning',
#  'central_heat',
#  'central_park_1',
#  'chef',
#  'chefs_kitchen',
#  'chelsea',
#  'children',
#  'children_playroom',
#  'childrens_playroom',
#  'childrens_room',
#  'cinema_room',
#  'citi_bike_station',
#  'citibikes_nearby',
#  'citihabitats',
#  'city_view',
#  'cleaning_and_auto_care',
#  'cleaning_service',
#  'cleaning_services',
#  'close_to_central_park',
#  'close_to_hospitals',
#  'close_to_nyc',
#  'close_to_subway',
#  'close_to_subway_',
#  'close_to_transit',
#  'closed_circuit_television_security_system',
#  'closet',
#  'closet_space',
#  'closets',
#  'closets_galore',
#  'club_room',
#  'club_room_w_billiards_tables',
#  'club_sun_deck_has_spectacular_city_and_river_views',
#  'cold_storage',
#  'cold_storage_in_lobby',
#  'com',
#  'combo_washer_dryer',
#  'come_live_the_good_life_for__less_',
#  'common',
#  'common_areas',
#  'common_backyard',
#  'common_balcony',
#  'common_courtyard',
#  'common_garden',
#  'common_outdoor_space',
#  'common_parking',
#  'common_roof_deck',
#  'common_storage',
#  'common_terrace',
#  'community_recreation_facilities',
#  'commuter',
#  'competitively_priced',
#  'complimentary_breakfast_on_weekdays',
#  'complimentary_continental_breakfast',
#  'complimentary_sunday_brunch',
#  'comprehensive_valet_services_including_maid_service',
#  'concierge',
#  'concierge_and_live',
#  'concierge_service',
#  'concierge_services',
#  'condo_finishes',
#  'condo_grade_finishes',
#  'continental_breakfast_served_5_days_a_week',
#  'control_',
#  'conv',
#  'convertible',
#  'convertible_1br',
#  'convertible_2',
#  'convertible_2_bedroom',
#  'convinient_to_all_major_transportation',
#  'corner_unit',
#  'counter',
#  'courtyard',
#  'crown_molding',
#  'crown_moldings',
#  'custom_lighting',
#  'custom_murals_on_the_ceiling_and_living_room_wall',
#  'custom_painted_murals',
#  'custom_window_treatments',
#  'deck',
#  'decks_with_river_views',
#  'deco_brick_wall',
#  'deco_brick_walls',
#  'deco_fireplace',
#  'decorative_fireplace',
#  'decorative_wooden_fireplace',
#  'designer_finishes',
#  'digital_tv',
#  'dining',
#  'dining_area',
#  'dining_room',
#  'diplomats_ok',
#  'direct_bus_line_to_ferry',
#  'dish_washer',
#  'dishwaser',
#  'dishwasher',
#  'dishwasher_',
#  'diswasher',
#  'dog_okay',
#  'dogs_allowed',
#  'dogs_ok',
#  'dogs_under_20_lbs',
#  'doorman',
#  'double_height_lobby_french_limestone_and_rojo_alicante_marble',
#  'double_hung_wooden_shutters',
#  'double_panned_sound',
#  'dry',
#  'dry_cleaning_service',
#  'dryer',
#  'dryer_',
#  'dryer_hookup',
#  'dryer_in',
#  'dryer_in_bldg',
#  'dryer_in_building',
#  'dryer_in_unit',
#  'dryer_inside_the_unit',
#  'duplex',
#  'duplex_layout',
#  'duplex_lounge',
#  'dw',
#  'dw__duplex___penthouse',
#  'dyer_combo',
#  'east_and_west_resident_lounges_reading_room_outdoor_lounges_with_river_views_party_room_chefs_kitchen_movie_screening_room_tot_spot_playroom_ping_pong',
#  'east_village',
#  'easy_qualification',
#  'easy_to_show',
#  'eat',
#  'eat_in_kitchen',
#  'electric_included',
#  'electricity_',
#  'electricity_included',
#  'electronic_keycard',
#  'electronic_rent_payment',
#  'electronic_rent_payment_',
#  'elegant_glass',
#  'elevator',
#  'elevator_',
#  'elevator_building',
#  'enclosed_private_lounge_with_magnificent_river_views',
#  'equal_king',
#  'equal_size_rooms',
#  'equipped_club_fitness_center',
#  'european_air_condition_in_each_room',
#  'everything_brand_new',
#  'exclusive',
#  'exclusive_rental',
#  'exclusive_residential_lounge_',
#  'executive_conference_room_with_large',
#  'exercise',
#  'exercise_equipment_',
#  'exercise_studio',
#  'expansive_living',
#  'expansive_sundeck',
#  'exposed_brick',
#  'exposed_brick_wall',
#  'exposed_brick_walls',
#  'exposed_brickhardwood_floors_microwaverenovated_open_view_excellent',
#  'exposed_bricks',
#  'extra_closet_space',
#  'extra_room',
#  'extra_storage',
#  'fan',
#  'features',
#  'featuring_a_sophisticated_precor',
#  'fee',
#  'fee_applies',
#  'fi',
#  'fi_access',
#  'fi_accessibility',
#  'finished_basement',
#  'fios_high_speed_internet',
#  'fire_place',
#  'fireplace',
#  'fireplace_storage',
#  'fireplaces',
#  'fitness',
#  'fitness_center',
#  'fitness_center_and_health_club',
#  'fitness_facility',
#  'fitness_room',
#  'flat',
#  'flat_screen_tv_and_sound_system',
#  'flex',
#  'flex_3_bed',
#  'flex_two_bed',
#  'flexible',
#  'flexible_viewing_times',
#  'floor',
#  'floor_to_ceiling_windows',
#  'four_barbecue_grills',
#  'four_hour_concierge_and_doorman',
#  'foyer',
#  'free_brealfast',
#  'free_cable_tv_and_wireless_internet',
#  'free_gym',
#  'free_health_club',
#  'free_month_',
#  'free_storage',
#  'free_wifi',
#  'free_wifi_in_club_lounge',
#  'french_door',
#  'french_doors',
#  'ft_doorman',
#  'full_floor',
#  'full_kitchen',
#  'full_service_garage',
#  'full_service_luxury_highrise',
#  'full_size_gym',
#  'full_skyline_view',
#  'fully',
#  'fully__equipped',
#  'fully_equipped_chef',
#  'fully_equipped_fitness_center_with_studio_for_classes',
#  'fully_equipped_gym',
#  'furnished',
#  'furnished_price',
#  'furnished_rental',
#  'furnished_wrap_around_terrace',
#  'game_center',
#  'game_room',
#  'garage',
#  'garage_attached',
#  'garage_fitness_facility_laundry_room_valet_lounge_billiards_room_rooftop_deck_wifi_access',
#  'garage_parking',
#  'garbage_disposal',
#  'garden',
#  'garden_roof_deck',
#  'gardening_area_with_rentable_plots',
#  'gas',
#  'gas_and_electric_included_in_rent',
#  'gas_included',
#  'gas_stove',
#  'gatehouse_security',
#  'gloved_doorman',
#  'golf_simulator',
#  'grab_it_or_grieve_it',
#  'gramercy',
#  'gramercy_park',
#  'grand_central',
#  'granite_bath',
#  'granite_bathroom',
#  'granite_counter',
#  'granite_counter_tops',
#  'granite_counters',
#  'granite_countertops',
#  'granite_kitchen',
#  'greal_location',
#  'great_area',
#  'great_closet_space',
#  'great_light_and_location',
#  'great_location',
#  'great_natural_light',
#  'great_river_views',
#  'great_share',
#  'great_view',
#  'great_views',
#  'great_views_of_the_neighborhood',
#  'green_building',
#  'gross_price_is_',
#  'ground_floor',
#  'guarantors_accepted',
#  'guarantors_okay',
#  'guest_suite_for_residents_only',
#  'gut_renovated',
#  'gut_renovation',
#  'gut_renovations',
#  'gym',
#  'gym_discount',
#  'gym_fitness_lounge_swimming_pool_sun_decks_exercise_studios_indoor_half',
#  'gym_in_building',
#  'half_bath',
#  'half_floor_through',
#  'hardwood',
#  'hardwood__floors',
#  'hardwood_floor',
#  'hardwood_flooring',
#  'hardwood_flooring_throughout',
#  'hardwood_floors',
#  'harwood_floors',
#  'health_club',
#  'health_club_',
#  'health_club_with_pool_on_the_top_floor',
#  'heat',
#  'heat_',
#  'heat_and_hot_water_included',
#  'heat_and_water_included_in_rent',
#  'heat_hot_water_included',
#  'heat_included',
#  'heated_lap_pool',
#  'herringbone_wood_floors',
#  'hi_rise',
#  'high',
#  'high_ceil',
#  'high_ceiling',
#  'high_ceilings',
#  'high_floor',
#  'high_floor_unit',
#  'high_speed_elevator',
#  'high_speed_internet',
#  'high_speed_internet_available',
#  'highhhhhh_ceilings',
#  'highland_park',
#  'highrise',
#  'historical_brownstone_originally_built_in_1901',
#  'home_office',
#  'home_office_',
#  'hot_water',
#  'hot_water_inc',
#  'hot_water_included',
#  'hour_attended_lobby',
#  'hour_concierge',
#  'hour_concierge_and_doorman',
#  'hour_doorman',
#  'hour_parking_garage_with_an_electric_vehicle_charging_station',
#  'hour_valet_parking_garage_',
#  'housekeeeping',
#  'housekeeping',
#  'housekeeping_',
#  'housekeeping_service',
#  'however_there',
#  'huge',
#  'huge_',
#  'huge_1_bedroom',
#  'huge_balcony',
#  'huge_bedrooms',
#  'huge_closets',
#  'huge_living_room',
#  'huge_private_backyard',
#  'huge_room',
#  'huge_rooms',
#  'huge_walk_in_closet',
#  'if_furnished',
#  'in_breakfast_bar',
#  'in_closet',
#  'in_closet_or_extra_room',
#  'in_closet_views',
#  ...]

# %%
np.random.seed(0)

folds = StratifiedKFold(y_train, n_folds=5, shuffle=True)
for train_index, test_index in folds:
    X_train2, X_test2 = X_train.loc[train_index], X_train.loc[test_index]
    y_train2, y_test2 = y_train[train_index], y_train[test_index]
    break

# %%
early_stopping_rounds = 100
learning_rate, max_depth, ss, cs, gamma, min_child_weight, reg_lambda, reg_alpha = 0.1, 6, 0.7, 0.7, 0, 1, 1, 0
#learning_rate, max_depth, ss, cs, gamma, min_child_weight, reg_lambda, reg_alpha = 0.1, 4, 0.8, 0.8, 0, 1, 1, 0
clf = XGBClassifier(max_depth=max_depth, learning_rate=learning_rate, n_estimators=5000, objective='multi:softprob', subsample=ss, colsample_bytree=cs, gamma=gamma, min_child_weight=min_child_weight, reg_lambda=reg_lambda, reg_alpha=reg_alpha)

X_train2 = csr_matrix(X_train2.values)
X_test2 = csr_matrix(X_test2.values)

clf.fit(X_train2, y_train2, eval_set=[(X_test2, y_test2)], eval_metric='mlogloss', early_stopping_rounds=early_stopping_rounds, verbose=100)
#[358]	validation_0-mlogloss:0.571967
# Out:
# Will train until validation_0 error hasn't decreased in 100 rounds.
# [0]	validation_0-mlogloss:1.037728
# [100]	validation_0-mlogloss:0.572477
# [200]	validation_0-mlogloss:0.563403
# [300]	validation_0-mlogloss:0.563054
# Stopping. Best iteration:
# [250]	validation_0-mlogloss:0.562200
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.7,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=6,
#        min_child_weight=1, missing=None, n_estimators=5000, nthread=-1,
#        objective='multi:softprob', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=0.7)

# %%
clf = RandomForestClassifier(n_estimators=1000)
clf.fit(X_train2, y_train2)
y_pred = clf.predict_proba(X_test2)
log_loss(y_test2, y_pred)
#0.60083096265660485
# Out:
# 0.59390945436383891

# %%
for x in X_train2.columns:
    inf = (X_train2[x] == np.inf).sum()
    if inf > 0:
        print(x, inf)

# %%
X_train.loc[X_train.price_per_bed == np.inf, 'price_per_bed'] = 1000000
X_train.loc[X_train.price_per_room == np.inf, 'price_per_room'] = 1000000

# %%
temp = pd.concat([X_train2.manager_id, pd.get_dummies(y_train)], axis = 1).groupby('manager_id').mean()
temp.columns = ['high_frac', 'medium_frac', 'low_frac']
temp['manager_listings'] = X_train2.groupby('manager_id').count().iloc[:,1]
temp['manager_skill'] = temp['high_frac']*2 + temp['medium_frac']

unranked_managers_ixes = temp['manager_listings'] < 20
ranked_managers_ixes = ~unranked_managers_ixes
mean_values = temp.loc[ranked_managers_ixes, ['high_frac', 'medium_frac', 'low_frac', 'manager_skill']].mean()
temp.loc[unranked_managers_ixes, ['high_frac', 'medium_frac', 'low_frac', 'manager_skill']] = mean_values.values

temp = temp['manager_skill']

#join
X_train2 = X_train2.merge(temp.reset_index(), how='left', left_on='manager_id', right_on='manager_id')

X_test2 = X_test2.merge(temp.reset_index(), how='left', left_on='manager_id', right_on='manager_id')
new_manager_ixes = X_test2['manager_skill'].isnull()
X_test2.loc[new_manager_ixes, 'manager_skill'] = mean_values['manager_skill']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import log_loss

# %%
X_train2
# Out:
# <39481x22 sparse matrix of type '<class 'numpy.float64'>'
# 	with 806988 stored elements in Compressed Sparse Row format>

# %%
X_train2
# Out:
#        bathrooms  bedrooms  building_id  display_address  latitude  \
# 0            1.5         3         3797            10410   40.7145
# 1            1.0         2         8986             8261   40.7947
# 2            1.0         1         8889            11414   40.7388
# 3            1.0         1         1848             9354   40.7539
# 4            1.0         4            0            12263   40.8241
# 5            2.0         4         2544            12352   40.7429
# 7            2.0         1          169            12371   40.7427
# 8            1.0         1         7635             9943   40.8234
# 9            2.0         4            0             6009   40.7278
# 10           1.0         0            0            12719   40.7769
# 11           1.0         1            0            11935   40.8448
# 13           2.0         2            0            12495   40.7707
# 14           1.0         1            0             9382   40.7584
# 15           1.0         0         8717             9297   40.7439
# 16           1.0         2         4565             2567   40.7305
# 18           1.0         4         9289            12177   40.7999
# 20           1.0         3         1480            10344   40.7454
# 21           1.0         2        10744             8562   40.7427
# 22           1.0         1         1205             9300   40.7447
# 23           1.0         1         7543            10245   40.7074
# 24           2.0         4          270            11543   40.7391
# 25           3.5         4         3141             9380   40.7584
# 26           1.0         1         9768             8802   40.7728
# 28           1.0         1        10903             1356   40.8335
# 29           2.0         2        10931             8781   40.7716
# 30           1.0         0          749             3532   40.7897
# 31           1.0         2          511            11871   40.7902
# 32           1.0         1         5640             8173   40.7179
# 35           1.0         1            0             9128   40.7900
# 37           1.0         0         5704            12488   40.7649
# ...          ...       ...          ...              ...       ...
# 49318        1.0         3         8528            12104   40.7080
# 49319        1.0         2         8660            11184   40.7231
# 49320        1.0         1          254            12474   40.7669
# 49321        2.0         2         7890            10667   40.7160
# 49322        1.0         1            0            10652   40.7176
# 49323        1.0         1        10319            11757   40.7655
# 49325        1.0         2        11444            10877   40.6182
# 49326        2.0         2            0            12560   40.7829
# 49327        1.0         1         6701             7451   40.7637
# 49328        1.0         1            0            11184   40.7293
# 49329        1.0         2         5859            12120   40.7075
# 49330        1.0         1            0             9181   40.7287
# 49331        1.5         0         9670            12719   40.7769
# 49333        1.0         1        10319            12488   40.7655
# 49334        2.0         2            0            10587   40.7095
# 49335        1.0         1         5054             7939   40.7179
# 49336        2.0         3         7915             9332   40.7222
# 49337        1.0         0        11255             8768   40.7708
# 49338        2.0         3         7458             9509   40.7766
# 49339        1.0         3         7398             9438   40.7695
# 49340        1.0         1        10408             9612   40.6865
# 49341        1.0         0         9533            10068   40.7090
# 49342        1.0         1         4428            11727   40.7645
# 49343        1.0         1         6453             8765   40.7728
# 49344        1.0         1         2605             8175   40.7350
# 49345        1.0         1            0             9516   40.7889
# 49346        1.0         1         2675             9135   40.7296
# 49348        1.0         1         7187            10858   40.7102
# 49349        1.0         1         5532            12436   40.7601
# 49351        1.0         2         3669            10744   40.8699
#
#        listing_id  longitude  manager_id  price  street_address  \
# 0         7211212   -73.9425        1568   3000           19652
# 1         7150865   -73.9667        1988   5465           19804
# 2         6887163   -74.0018        3733   2850            8190
# 3         6888711   -73.9677         282   3275           11851
# 4         6934781   -73.9493        2618   3350           16045
# 5         6894514   -74.0028        3081   7995           12696
# 7         6867392   -73.9957        3959   5645            3487
# 8         6898799   -73.9457        3339   1725           18260
# 9         6814332   -73.9808         633   5800           16669
# 10        6869199   -73.9467        3901   1950            4148
# 11        7102986   -73.9396         819   1675           18460
# 13        6846213   -73.9817         982   6895            9868
# 14        7089402   -73.9648        2009   3050           10901
# 15        6889043   -73.9743        3779   2350           12221
# 16        6913348   -73.9830          62   3650            6419
# 18        6900220   -73.9638        2452   5000            1959
# 20        6858062   -73.9845         969   4395            1672
# 21        6836760   -73.9794        3959   2999            6151
# 22        6866830   -73.9741        2452   2595           11482
# 23        6885927   -74.0081        1883   3695             296
# 24        7120132   -73.9936         224   7400            9854
# 25        6933499   -73.9653        2991   7500           10631
# 26        6921632   -73.9502        1369   2295           15067
# 28        6907079   -73.9141         327   1350            1694
# 29        6925264   -73.9506        2082   5600           14813
# 30        6904268   -73.9760        2523   2750            8750
# 31        6821944   -73.9678        3261   3500           15976
# 32        6912559   -74.0148        2725   5165           13591
# 35        6890107   -73.9418        1162   1650           10757
# 37        6885742   -73.9763         898   1980           17544
# ...           ...        ...         ...    ...             ...
# 49318     6877135   -74.0149        2084   3800           20316
# 49319     6833059   -74.0044        1619   3625            8585
# 49320     7100242   -73.9917        3587   2727           15166
# 49321     6887906   -74.0148        4111  10650            5455
# 49322     6921019   -73.9531        2984   3126            8718
# 49323     6926146   -73.9785        3049   3325            3188
# 49325     6943991   -74.0360        3624   3500           20470
# 49326     6822618   -73.9731        2166  11950            8600
# 49327     6918969   -73.9847        3882   2980           20223
# 49328     6921162   -73.9987        1742   2850            7527
# 49329     6819357   -74.0043        1894   2885            5496
# 49330     6893263   -73.9808        1329   2950           16255
# 49331     6873182   -73.9467        3735   2650            4148
# 49333     6924210   -73.9785        1589   3475            3207
# 49334     6884807   -74.0084         687   5815           21248
# 49335     6825168   -73.9989        1210   2050            1474
# 49336     6911061   -73.9824         565   4600            6975
# 49337     6942494   -73.9525        4357   2000           14518
# 49338     6819478   -73.9463         831   9200           16084
# 49339     6878391   -73.9603        4291   4550            5441
# 49340     6871559   -73.9134         889   1900           16301
# 49341     6933865   -74.0105          66   2500            1329
# 49342     6837242   -73.9840        3959   2500            9067
# 49343     6815109   -73.9591        2983   2675            5049
# 49344     6871681   -74.0007        4283   3645           17765
# 49345     6856001   -73.9719        3291   2179            1383
# 49346     6913833   -73.9869        4011   4500            4108
# 49348     6822449   -74.0163        4113   3950            7141
# 49349     6881461   -73.9900        3724   2595           12292
# 49351     6858245   -73.9172        3713   2200            9843
#
#            ...        created_day_of_year  created_hour  created_weekday  \
# 0          ...                        176             7                4
# 1          ...                        164            12                6
# 2          ...                        108             3                6
# 3          ...                        109             2                0
# 4          ...                        119             1                3
# 5          ...                        110             4                1
# 7          ...                        104             6                2
# 8          ...                        111             2                2
# 9          ...                         93             2                5
# 10         ...                        105             1                3
# 11         ...                        155             3                4
# 13         ...                        100             1                5
# 14         ...                        153             3                2
# 15         ...                        109             2                0
# 16         ...                        113             5                4
# 18         ...                        111             4                2
# 20         ...                        103             2                1
# 21         ...                         98             2                3
# 22         ...                        104             5                2
# 23         ...                        108             2                6
# 24         ...                        159             4                1
# 25         ...                        118             6                2
# 26         ...                        116             2                0
# 28         ...                        112             5                3
# 29         ...                        117             2                1
# 30         ...                        112             2                3
# 31         ...                         95             4                0
# 32         ...                        113             4                4
# 35         ...                        109             3                0
# 37         ...                        108             2                6
# ...        ...                        ...           ...              ...
# 49318      ...                        106             4                4
# 49319      ...                         97             7                2
# 49320      ...                        154            13                3
# 49321      ...                        108             5                6
# 49322      ...                        116             1                0
# 49323      ...                        117             4                1
# 49325      ...                        120            15                4
# 49326      ...                         96             1                1
# 49327      ...                        115             3                6
# 49328      ...                        116             1                0
# 49329      ...                         94             3                6
# 49330      ...                        110             2                1
# 49331      ...                        105             5                3
# 49333      ...                        117             2                1
# 49334      ...                        107            16                5
# 49335      ...                         96             4                1
# 49336      ...                        113             3                4
# 49337      ...                        120             5                4
# 49338      ...                         94             5                6
# 49339      ...                        106             5                4
# 49340      ...                        105             3                3
# 49341      ...                        118            12                2
# 49342      ...                         98             2                3
# 49343      ...                         93             3                5
# 49344      ...                        105             3                3
# 49345      ...                        102             3                0
# 49346      ...                        113            15                4
# 49348      ...                         95            18                0
# 49349      ...                        107             2                5
# 49351      ...                        103             2                1
#
#            logx      logy    radius  photos_count  description_words_count  \
# 0      3.706584  3.260306 -7.446341             5                       65
# 1      3.708552  3.259376 -5.639716            11                        0
# 2      3.707181  3.258027 -5.898510             8                       60
# 3      3.707552  3.259338 -7.421907             3                       38
# 4      3.709273  3.260045 -4.896160             3                       47
# 5      3.707282  3.257989 -5.851502             5                        0
# 7      3.707277  3.258262 -6.134814             5                       99
# 8      3.709255  3.260183 -4.910527             5                        0
# 9      3.706911  3.258835 -6.830186             9                       92
# 10     3.708116  3.260144 -6.470295             1                       15
# 11     3.709780  3.260417 -4.458491             5                       65
# 13     3.707964  3.258800 -6.149754             6                       57
# 14     3.707662  3.259449 -7.312631             6                       53
# 15     3.707306  3.259085 -7.327079             2                       49
# 16     3.706977  3.258750 -6.744228             5                       37
# 18     3.708680  3.259488 -5.501021             0                        0
# 20     3.707343  3.258693 -6.653250             6                      101
# 21     3.707277  3.258889 -6.987285             5                       32
# 22     3.707326  3.259092 -7.325941             0                        0
# 23     3.706410  3.257785 -5.436159             4                       99
# 24     3.707188  3.258343 -6.238514             6                      100
# 25     3.707662  3.259430 -7.289491             7                       82
# 26     3.708015  3.260010 -6.695257             6                       43
# 28     3.709503  3.261395 -4.562349             1                       11
# 29     3.707986  3.259995 -6.764006             1                       32
# 30     3.708430  3.259019 -5.679309             4                      131
# 31     3.708442  3.259334 -5.776422             8                       76
# 32     3.706668  3.257527 -5.368226             5                       32
# 35     3.708437  3.260332 -5.878215             3                       81
# 37     3.707821  3.259008 -6.526005             2                       79
# ...         ...       ...       ...           ...                      ...
# 49318  3.706425  3.257523 -5.265976             4                      217
# 49319  3.706795  3.257927 -5.734444             4                       60
# 49320  3.707870  3.258416 -5.936025             5                       26
# 49321  3.706621  3.257527 -5.351504             7                       27
# 49322  3.706660  3.259899 -7.787069             6                       54
# 49323  3.707836  3.258923 -6.424732             9                        0
# 49325  3.704216  3.256711 -3.827694             6                       46
# 49326  3.708263  3.259131 -5.948988             2                       55
# 49327  3.707792  3.258685 -6.253988             3                       77
# 49328  3.706948  3.258147 -5.992788             3                       20
# 49329  3.706412  3.257931 -5.541989             4                       74
# 49330  3.706933  3.258835 -6.845951             4                       61
# 49331  3.708116  3.260144 -6.470295             7                       25
# 49333  3.707836  3.258923 -6.424732             1                      137
# 49334  3.706461  3.257773 -5.456405             8                       43
# 49335  3.706668  3.258139 -5.865160             3                       47
# 49336  3.706773  3.258773 -6.626219             8                       83
# 49337  3.707966  3.259922 -6.804351             3                       65
# 49338  3.708108  3.260160 -6.484024             4                       46
# 49339  3.707934  3.259622 -6.782813             4                       67
# 49340  3.705896  3.261422 -5.543240             0                        0
# 49341  3.706449  3.257693 -5.392775             4                       65
# 49342  3.707812  3.258712 -6.257399             3                       92
# 49343  3.708015  3.259668 -6.622872             4                       36
# 49344  3.707088  3.258070 -5.938810             5                       31
# 49345  3.708410  3.259177 -5.766009             8                       59
# 49346  3.706955  3.258600 -6.523619             8                       42
# 49348  3.706479  3.257469 -5.254485             8                      113
# 49349  3.707704  3.258481 -6.142282             3                       68
# 49351  3.710394  3.261276 -3.988280             7                       75
#
#        description_uppercase  manager_skill
# 0                          0       0.253333
# 1                          0       0.013333
# 2                          0       0.495327
# 3                          0       0.301370
# 4                          0       0.413298
# 5                          0       0.127907
# 7                          0       0.742857
# 8                          0       0.413298
# 9                          0       0.000000
# 10                         0       0.413298
# 11                         0       0.413298
# 13                         0       0.553571
# 14                         0       0.413298
# 15                         0       0.015106
# 16                         0       0.200000
# 18                         0       0.015106
# 20                         0       0.433333
# 21                         0       0.080972
# 22                         0       0.231405
# 23                         0       1.445946
# 24                         1       0.064516
# 25                         0       0.413298
# 26                         0       0.413298
# 28                         0       0.413298
# 29                         0       0.413298
# 30                         0       0.080972
# 31                         0       0.014085
# 32                         0       0.642857
# 35                         0       0.452381
# 37                         0       0.379412
# ...                      ...            ...
# 49318                      0            NaN
# 49319                      0            NaN
# 49320                      0            NaN
# 49321                      0            NaN
# 49322                      0            NaN
# 49323                      0            NaN
# 49325                      0            NaN
# 49326                      0            NaN
# 49327                      0            NaN
# 49328                      0            NaN
# 49329                      1            NaN
# 49330                      0            NaN
# 49331                      0            NaN
# 49333                      0            NaN
# 49334                      0            NaN
# 49335                      0            NaN
# 49336                      1            NaN
# 49337                      0            NaN
# 49338                      0            NaN
# 49339                      0            NaN
# 49340                      0            NaN
# 49341                      0            NaN
# 49342                      1            NaN
# 49343                      0            NaN
# 49344                      0            NaN
# 49345                      0            NaN
# 49346                      0            NaN
# 49348                      0            NaN
# 49349                      0            NaN
# 49351                      0            NaN
#
# [39481 rows x 22 columns]
